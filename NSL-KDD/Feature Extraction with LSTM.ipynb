# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from tensorflow.keras.utils import plot_model
# Out:
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25186         0           tcp      exec  RSTO          0          0     0
# 25187         0           tcp  ftp_data    SF        334          0     0
# 25188         0           tcp   private   REJ          0          0     0
# 25189         0           tcp      nnsp    S0          0          0     0
# 25190         0           tcp    finger    S0          0          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.00
# 1                   0       0    0  ...                    0.10
# 2                   0       0    0  ...                    1.00
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 25186               0       0    0  ...                    0.03
# 25187               0       0    0  ...                    1.00
# 25188               0       0    0  ...                    0.05
# 25189               0       0    0  ...                    0.08
# 25190               0       0    0  ...                    0.19
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 25186                    0.06                         0.00
# 25187                    0.00                         1.00
# 25188                    0.07                         0.00
# 25189                    0.06                         0.00
# 25190                    0.03                         0.01
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 25186                         0.00                  0.00
# 25187                         0.18                  0.00
# 25188                         0.00                  0.00
# 25189                         0.00                  1.00
# 25190                         0.00                  1.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                   0.0
# 1                          1.00                   0.0
# 2                          0.01                   0.0
# 3                          0.00                   0.0
# 4                          0.00                   1.0
# ...                         ...                   ...
# 25186                      0.00                   1.0
# 25187                      0.00                   0.0
# 25188                      0.00                   1.0
# 25189                      1.00                   0.0
# 25190                      1.00                   0.0
#
#        Dst_host_srv_rerror_rate  attack_type  difficulty_level
# 0                          0.00       normal                15
# 1                          0.00      neptune                19
# 2                          0.01       normal                21
# 3                          0.00       normal                21
# 4                          1.00      neptune                21
# ...                         ...          ...               ...
# 25186                      1.00      neptune                19
# 25187                      0.00  warezclient                12
# 25188                      1.00      neptune                21
# 25189                      0.00      neptune                20
# 25190                      0.00      neptune                18
#
# [25191 rows x 43 columns]

# %%
test_data
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0            13           tcp    telnet    SF        118       2425     0
# 1             0           udp   private    SF         44          0     0
# 2             0           tcp    telnet    S3          0         44     0
# 3             0           udp   private    SF         53         55     0
# 4             0           tcp   private    SH          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 11845         0           udp  domain_u    SF         43         43     0
# 11846         0           tcp      http    SF        336        285     0
# 11847         1           tcp    telnet  RSTO          0         15     0
# 11848         0           tcp    sunrpc   REJ          0          0     0
# 11849         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.38
# 1                   0       0    0  ...                    1.00
# 2                   0       0    0  ...                    0.31
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.06
# ...               ...     ...  ...  ...                     ...
# 11845               0       0    0  ...                    1.00
# 11846               0       0    0  ...                    0.92
# 11847               0       0    0  ...                    0.37
# 11848               0       0    0  ...                    0.19
# 11849               0       0    0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.12                         0.04
# 1                        0.01                         0.01
# 2                        0.61                         0.00
# 3                        0.00                         0.87
# 4                        1.00                         1.00
# ...                       ...                          ...
# 11845                    0.00                         0.01
# 11846                    0.02                         0.00
# 11847                    0.03                         0.01
# 11848                    0.03                         0.01
# 11849                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  0.00
# 2                             0.00                  0.21
# 3                             0.00                  0.00
# 4                             0.00                  1.00
# ...                            ...                   ...
# 11845                         0.00                  0.00
# 11846                         0.00                  0.00
# 11847                         0.02                  0.05
# 11848                         0.04                  0.00
# 11849                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.12
# 1                          0.00                  0.00
# 2                          0.68                  0.60
# 3                          0.00                  0.00
# 4                          1.00                  0.00
# ...                         ...                   ...
# 11845                      0.00                  0.00
# 11846                      0.00                  0.05
# 11847                      0.08                  0.85
# 11848                      0.00                  0.88
# 11849                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate   attack_type  difficulty_level
# 0                          0.30  guess_passwd                 2
# 1                          0.00     snmpguess                12
# 2                          0.00  processtable                18
# 3                          0.00        normal                17
# 4                          0.00          nmap                17
# ...                         ...           ...               ...
# 11845                      0.00        normal                18
# 11846                      0.00        normal                18
# 11847                      0.58         mscan                13
# 11848                      1.00         mscan                15
# 11849                      0.00     snmpguess                17
#
# [11850 rows x 43 columns]

# %%
df= pd.concat([train_data, test_data], ignore_index=True)
df
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 37036         0           udp  domain_u    SF         43         43     0
# 37037         0           tcp      http    SF        336        285     0
# 37038         1           tcp    telnet  RSTO          0         15     0
# 37039         0           tcp    sunrpc   REJ          0          0     0
# 37040         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.00
# 1                   0       0    0  ...                    0.10
# 2                   0       0    0  ...                    1.00
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 37036               0       0    0  ...                    1.00
# 37037               0       0    0  ...                    0.92
# 37038               0       0    0  ...                    0.37
# 37039               0       0    0  ...                    0.19
# 37040               0       0    0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 37036                    0.00                         0.01
# 37037                    0.02                         0.00
# 37038                    0.03                         0.01
# 37039                    0.03                         0.01
# 37040                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 37036                         0.00                  0.00
# 37037                         0.00                  0.00
# 37038                         0.02                  0.05
# 37039                         0.04                  0.00
# 37040                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.00
# 1                          1.00                  0.00
# 2                          0.01                  0.00
# 3                          0.00                  0.00
# 4                          0.00                  1.00
# ...                         ...                   ...
# 37036                      0.00                  0.00
# 37037                      0.00                  0.05
# 37038                      0.08                  0.85
# 37039                      0.00                  0.88
# 37040                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate  attack_type  difficulty_level
# 0                          0.00       normal                15
# 1                          0.00      neptune                19
# 2                          0.01       normal                21
# 3                          0.00       normal                21
# 4                          1.00      neptune                21
# ...                         ...          ...               ...
# 37036                      0.00       normal                18
# 37037                      0.00       normal                18
# 37038                      0.58        mscan                13
# 37039                      1.00        mscan                15
# 37040                      0.00    snmpguess                17
#
# [37041 rows x 43 columns]

# %%
df = df.rename(columns={'attack_type': 'Label', 'difficulty_level': 'Difficulty'})
df
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 37036         0           udp  domain_u    SF         43         43     0
# 37037         0           tcp      http    SF        336        285     0
# 37038         1           tcp    telnet  RSTO          0         15     0
# 37039         0           tcp    sunrpc   REJ          0          0     0
# 37040         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.00
# 1                   0       0    0  ...                    0.10
# 2                   0       0    0  ...                    1.00
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 37036               0       0    0  ...                    1.00
# 37037               0       0    0  ...                    0.92
# 37038               0       0    0  ...                    0.37
# 37039               0       0    0  ...                    0.19
# 37040               0       0    0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 37036                    0.00                         0.01
# 37037                    0.02                         0.00
# 37038                    0.03                         0.01
# 37039                    0.03                         0.01
# 37040                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 37036                         0.00                  0.00
# 37037                         0.00                  0.00
# 37038                         0.02                  0.05
# 37039                         0.04                  0.00
# 37040                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.00
# 1                          1.00                  0.00
# 2                          0.01                  0.00
# 3                          0.00                  0.00
# 4                          0.00                  1.00
# ...                         ...                   ...
# 37036                      0.00                  0.00
# 37037                      0.00                  0.05
# 37038                      0.08                  0.85
# 37039                      0.00                  0.88
# 37040                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate      Label  Difficulty
# 0                          0.00     normal          15
# 1                          0.00    neptune          19
# 2                          0.01     normal          21
# 3                          0.00     normal          21
# 4                          1.00    neptune          21
# ...                         ...        ...         ...
# 37036                      0.00     normal          18
# 37037                      0.00     normal          18
# 37038                      0.58      mscan          13
# 37039                      1.00      mscan          15
# 37040                      0.00  snmpguess          17
#
# [37041 rows x 43 columns]

# %%
df.drop(['Difficulty'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37041 entries, 0 to 37040
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Duration                     37041 non-null  int64
#  1   Protocol_type                37041 non-null  object
#  2   Service                      37041 non-null  object
#  3   Flag                         37041 non-null  object
#  4   Src_bytes                    37041 non-null  int64
#  5   Dst_bytes                    37041 non-null  int64
#  6   Land                         37041 non-null  int64
#  7   Wrong_fragment               37041 non-null  int64
#  8   Urgent                       37041 non-null  int64
#  9   Hot                          37041 non-null  int64
#  10  Num_failed_logins            37041 non-null  int64
#  11  Logged_in                    37041 non-null  int64
#  12  Num_compromised              37041 non-null  int64
#  13  Root_shell                   37041 non-null  int64
#  14  Su_attempted                 37041 non-null  int64
#  15  Num_root                     37041 non-null  int64
#  16  Num_file_creations           37041 non-null  int64
#  17  Num_shells                   37041 non-null  int64
#  18  Num_access_files             37041 non-null  int64
#  19  Num_outbound_cmds            37041 non-null  int64
#  20  Is_hot_login                 37041 non-null  int64
#  21  Is_guest_login               37041 non-null  int64
#  22  Count                        37041 non-null  int64
#  23  Srv_count                    37041 non-null  int64
#  24  Serror_rate                  37041 non-null  float64
#  25  Srv_serror_rate              37041 non-null  float64
#  26  Rerror_rate                  37041 non-null  float64
#  27  Srv_rerror_rate              37041 non-null  float64
#  28  Same_srv_rate                37041 non-null  float64
#  29  Diff_srv_rate                37041 non-null  float64
#  30  Srv_diff_host_rate           37041 non-null  float64
#  31  Dst_host_count               37041 non-null  int64
#  32  Dst_host_srv_count           37041 non-null  int64
#  33  Dst_host_same_srv_rate       37041 non-null  float64
#  34  Dst_host_diff_srv_rate       37041 non-null  float64
#  35  Dst_host_same_src_port_rate  37041 non-null  float64
#  36  Dst_host_srv_diff_host_rate  37041 non-null  float64
#  37  Dst_host_serror_rate         37041 non-null  float64
#  38  Dst_host_srv_serror_rate     37041 non-null  float64
#  39  Dst_host_rerror_rate         37041 non-null  float64
#  40  Dst_host_srv_rerror_rate     37041 non-null  float64
#  41  Label                        37041 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 11.9+ MB

# %%
df.columns
# Out:
# Index(['Duration', 'Protocol_type', 'Service', 'Flag', 'Src_bytes',
#        'Dst_bytes', 'Land', 'Wrong_fragment', 'Urgent', 'Hot',
#        'Num_failed_logins', 'Logged_in', 'Num_compromised', 'Root_shell',
#        'Su_attempted', 'Num_root', 'Num_file_creations', 'Num_shells',
#        'Num_access_files', 'Num_outbound_cmds', 'Is_hot_login',
#        'Is_guest_login', 'Count', 'Srv_count', 'Serror_rate',
#        'Srv_serror_rate', 'Rerror_rate', 'Srv_rerror_rate', 'Same_srv_rate',
#        'Diff_srv_rate', 'Srv_diff_host_rate', 'Dst_host_count',
#        'Dst_host_srv_count', 'Dst_host_same_srv_rate',
#        'Dst_host_diff_srv_rate', 'Dst_host_same_src_port_rate',
#        'Dst_host_srv_diff_host_rate', 'Dst_host_serror_rate',
#        'Dst_host_srv_serror_rate', 'Dst_host_rerror_rate',
#        'Dst_host_srv_rerror_rate', 'Label'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Duration                       0
# Protocol_type                  0
# Service                        0
# Flag                           0
# Src_bytes                      0
# Dst_bytes                      0
# Land                           0
# Wrong_fragment                 0
# Urgent                         0
# Hot                            0
# Num_failed_logins              0
# Logged_in                      0
# Num_compromised                0
# Root_shell                     0
# Su_attempted                   0
# Num_root                       0
# Num_file_creations             0
# Num_shells                     0
# Num_access_files               0
# Num_outbound_cmds              0
# Is_hot_login                   0
# Is_guest_login                 0
# Count                          0
# Srv_count                      0
# Serror_rate                    0
# Srv_serror_rate                0
# Rerror_rate                    0
# Srv_rerror_rate                0
# Same_srv_rate                  0
# Diff_srv_rate                  0
# Srv_diff_host_rate             0
# Dst_host_count                 0
# Dst_host_srv_count             0
# Dst_host_same_srv_rate         0
# Dst_host_diff_srv_rate         0
# Dst_host_same_src_port_rate    0
# Dst_host_srv_diff_host_rate    0
# Dst_host_serror_rate           0
# Dst_host_srv_serror_rate       0
# Dst_host_rerror_rate           0
# Dst_host_srv_rerror_rate       0
# Label                          0
# dtype: int64

# %%
df['Label'].value_counts()
# Out:
# normal             15600
# neptune             9861
# satan               1418
# guess_passwd        1241
# smurf               1156
# mscan                996
# warezmaster          951
# ipsweep              851
# portsweep            743
# apache2              737
# processtable         685
# back                 555
# nmap                 374
# snmpguess            331
# saint                309
# mailbomb             293
# teardrop             200
# warezclient          181
# snmpgetattack        178
# httptunnel           133
# pod                   79
# buffer_overflow       26
# multihop              20
# named                 17
# rootkit               17
# ps                    15
# sendmail              14
# xterm                 13
# xlock                  9
# land                   8
# imap                   6
# phf                    4
# xsnoop                 4
# ftp_write              4
# loadmodule             3
# worm                   2
# udpstorm               2
# perl                   2
# sqlattack              2
# spy                    1
# Name: Label, dtype: int64

# %%
# Redistribute across common attack class
def change_label(df):
  df.Label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.Label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail','snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)      
  df.Label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.Label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(df)

# %%
df
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 37036         0           udp  domain_u    SF         43         43     0
# 37037         0           tcp      http    SF        336        285     0
# 37038         1           tcp    telnet  RSTO          0         15     0
# 37039         0           tcp    sunrpc   REJ          0          0     0
# 37040         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_srv_count  \
# 0                   0       0    0  ...                   1
# 1                   0       0    0  ...                  26
# 2                   0       0    0  ...                 255
# 3                   0       0    0  ...                 255
# 4                   0       0    0  ...                  19
# ...               ...     ...  ...  ...                 ...
# 37036               0       0    0  ...                 255
# 37037               0       0    0  ...                 234
# 37038               0       0    0  ...                  96
# 37039               0       0    0  ...                  52
# 37040               0       0    0  ...                 255
#
#        Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0                        0.00                    0.60
# 1                        0.10                    0.05
# 2                        1.00                    0.00
# 3                        1.00                    0.00
# 4                        0.07                    0.07
# ...                       ...                     ...
# 37036                    1.00                    0.00
# 37037                    0.92                    0.02
# 37038                    0.37                    0.03
# 37039                    0.19                    0.03
# 37040                    1.00                    0.00
#
#        Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 0                             0.88                         0.00
# 1                             0.00                         0.00
# 2                             0.03                         0.04
# 3                             0.00                         0.00
# 4                             0.00                         0.00
# ...                            ...                          ...
# 37036                         0.01                         0.00
# 37037                         0.00                         0.00
# 37038                         0.01                         0.02
# 37039                         0.01                         0.04
# 37040                         0.00                         0.00
#
#        Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.00
# 1                      1.00                      1.00                  0.00
# 2                      0.03                      0.01                  0.00
# 3                      0.00                      0.00                  0.00
# 4                      0.00                      0.00                  1.00
# ...                     ...                       ...                   ...
# 37036                  0.00                      0.00                  0.00
# 37037                  0.00                      0.00                  0.05
# 37038                  0.05                      0.08                  0.85
# 37039                  0.00                      0.00                  0.88
# 37040                  0.00                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate   Label
# 0                          0.00  normal
# 1                          0.00     Dos
# 2                          0.01  normal
# 3                          0.00  normal
# 4                          1.00     Dos
# ...                         ...     ...
# 37036                      0.00  normal
# 37037                      0.00  normal
# 37038                      0.58   Probe
# 37039                      1.00   Probe
# 37040                      0.00     R2L
#
# [37041 rows x 42 columns]

# %%
df['Label'].value_counts()
# Out:
# normal    15600
# Dos       13578
# Probe      4691
# R2L        3094
# U2R          78
# Name: Label, dtype: int64

# %%
Label = pd.DataFrame(df.Label)

# %%
std_scaler = MinMaxScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = df.select_dtypes(include='number').columns
df = standardization(df,numeric_col)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = Label.apply(le2.fit_transform)
df['intrusion'] = enc_label
print(df.shape)
df
# Out:
# (37041, 43)
#        Duration Protocol_type   Service  Flag     Src_bytes  Dst_bytes  Land  \
# 0      0.000000           udp     other    SF  3.824902e-07   0.000000   0.0
# 1      0.000000           tcp   private    S0  0.000000e+00   0.000000   0.0
# 2      0.000000           tcp      http    SF  6.077927e-07   0.001583   0.0
# 3      0.000000           tcp      http    SF  5.213394e-07   0.000082   0.0
# 4      0.000000           tcp   private   REJ  0.000000e+00   0.000000   0.0
# ...         ...           ...       ...   ...           ...        ...   ...
# 37036  0.000000           udp  domain_u    SF  1.126512e-07   0.000008   0.0
# 37037  0.000000           tcp      http    SF  8.802515e-07   0.000055   0.0
# 37038  0.000017           tcp    telnet  RSTO  0.000000e+00   0.000003   0.0
# 37039  0.000000           tcp    sunrpc   REJ  0.000000e+00   0.000000   0.0
# 37040  0.000000           udp   private    SF  1.074116e-07   0.000000   0.0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                 0.0     0.0  0.0  ...                    0.00
# 1                 0.0     0.0  0.0  ...                    0.10
# 2                 0.0     0.0  0.0  ...                    1.00
# 3                 0.0     0.0  0.0  ...                    1.00
# 4                 0.0     0.0  0.0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 37036             0.0     0.0  0.0  ...                    1.00
# 37037             0.0     0.0  0.0  ...                    0.92
# 37038             0.0     0.0  0.0  ...                    0.37
# 37039             0.0     0.0  0.0  ...                    0.19
# 37040             0.0     0.0  0.0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 37036                    0.00                         0.01
# 37037                    0.02                         0.00
# 37038                    0.03                         0.01
# 37039                    0.03                         0.01
# 37040                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 37036                         0.00                  0.00
# 37037                         0.00                  0.00
# 37038                         0.02                  0.05
# 37039                         0.04                  0.00
# 37040                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.00
# 1                          1.00                  0.00
# 2                          0.01                  0.00
# 3                          0.00                  0.00
# 4                          0.00                  1.00
# ...                         ...                   ...
# 37036                      0.00                  0.00
# 37037                      0.00                  0.05
# 37038                      0.08                  0.85
# 37039                      0.00                  0.88
# 37040                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate   Label  intrusion
# 0                          0.00  normal          4
# 1                          0.00     Dos          0
# 2                          0.01  normal          4
# 3                          0.00  normal          4
# 4                          1.00     Dos          0
# ...                         ...     ...        ...
# 37036                      0.00  normal          4
# 37037                      0.00  normal          4
# 37038                      0.58   Probe          1
# 37039                      1.00   Probe          1
# 37040                      0.00     R2L          2
#
# [37041 rows x 43 columns]

# %%
df.drop(labels= ['Label'], axis=1, inplace=True)
print(df.shape)
# Out:
# (37041, 42)

# %%
# one-hot-encoding categorical columns
df = pd.get_dummies(df,columns=['Protocol_type','Service','Flag'],prefix="",prefix_sep="")  
print(df.shape)
# Out:
# (37041, 120)

# %%
y_data= df['intrusion']
X_data= df.drop(labels=['intrusion'], axis=1)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

# %%
X_data = X_data.astype(np.float32)
Y_data = y_data.astype(np.float32)
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data, test_size=0.20, random_state=42)
print(X_train.shape,'\n',X_test.shape)
# Out:
# (29632, 119)
#  (7409, 119)

# %%
from sklearn.feature_selection import SelectFromModel

sel = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1))
sel.fit(X_train, y_train)
sel.get_support()

X_train.columns

features = X_train.columns[sel.get_support()]
print(features)

print(len(features))

np.mean(sel.estimator_.feature_importances_)
print(sel.estimator_.feature_importances_)
# Out:
# Index(['Duration', 'Src_bytes', 'Dst_bytes', 'Hot', 'Logged_in', 'Count',
#        'Srv_count', 'Serror_rate', 'Srv_serror_rate', 'Rerror_rate',
#        'Srv_rerror_rate', 'Same_srv_rate', 'Diff_srv_rate',
#        'Srv_diff_host_rate', 'Dst_host_count', 'Dst_host_srv_count',
#        'Dst_host_same_srv_rate', 'Dst_host_diff_srv_rate',
#        'Dst_host_same_src_port_rate', 'Dst_host_srv_diff_host_rate',
#        'Dst_host_serror_rate', 'Dst_host_srv_serror_rate',
#        'Dst_host_rerror_rate', 'Dst_host_srv_rerror_rate', 'icmp', 'tcp',
#        'udp', 'eco_i', 'ecr_i', 'http', 'pop_3', 'S0', 'SF'],
#       dtype='object')
# 33
# [2.09396937e-02 3.91721310e-02 7.42906468e-02 4.93991562e-05
#  3.77900910e-03 1.41707692e-04 1.09764794e-02 6.10107682e-03
#  2.13254835e-02 5.58994595e-03 4.25644862e-04 7.23161895e-05
#  7.89126214e-04 4.72642013e-04 2.61970324e-04 2.76316966e-04
#  0.00000000e+00 1.28517712e-04 5.73216968e-03 4.98969176e-02
#  3.13441740e-02 2.33186125e-02 2.91368941e-02 1.65797193e-02
#  1.17568606e-02 4.74390683e-02 3.86636542e-02 1.52082806e-02
#  2.78063594e-02 3.71784333e-02 3.94770377e-02 3.86837661e-02
#  3.39083542e-02 2.68435228e-02 2.47182974e-02 4.09808474e-02
#  4.27654743e-02 2.50696237e-02 1.83211180e-02 8.94991174e-03
#  1.09705124e-02 2.85470892e-04 1.33938808e-04 1.45235302e-05
#  2.78716681e-04 5.55339443e-06 4.01117430e-05 1.05036330e-05
#  1.30467497e-05 8.76703323e-06 7.22409893e-06 1.41138183e-04
#  5.18736472e-03 9.14717706e-06 1.23633490e-02 1.31456919e-02
#  3.44655226e-06 5.03740355e-07 7.08246126e-04 5.19944494e-03
#  5.49208469e-03 2.98816537e-05 8.16744878e-06 1.44975489e-02
#  1.50350909e-05 1.16207640e-06 9.22284849e-04 2.04075559e-05
#  2.53136532e-06 2.15999189e-06 8.51542414e-07 1.27788869e-05
#  3.42029081e-05 1.15765611e-05 9.20715058e-06 8.05897984e-06
#  3.81135394e-06 7.24301937e-06 2.21500051e-06 1.18231140e-05
#  1.31062816e-05 4.14201807e-05 7.37985140e-03 2.36536873e-04
#  1.63727618e-06 1.31601026e-02 0.00000000e+00 7.39386535e-03
#  4.71238284e-06 1.93604909e-05 4.30418595e-06 7.21857039e-06
#  3.83312770e-03 3.00054784e-06 1.01762566e-05 4.76114134e-04
#  2.64718363e-05 6.72487342e-06 5.83312093e-03 0.00000000e+00
#  1.71014762e-04 2.21600698e-04 1.28492823e-05 5.23270634e-04
#  4.45839368e-05 3.05774719e-05 5.69221693e-06 5.06915532e-05
#  4.73571952e-05 2.22895107e-03 1.43667170e-03 1.35031949e-04
#  5.33798903e-03 2.53004419e-02 3.14274620e-04 6.39614668e-05
#  7.28948001e-04 3.53468710e-02 1.35743211e-03]

# %%
X_train_rfc = sel.transform(X_train)
X_test_rfc = sel.transform(X_test)

X_train_rfc=np.array(X_train_rfc)
X_test_rfc=np.array(X_test_rfc)
y_data=np.array(y_data)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train_rfc, ( X_train_rfc.shape[0], 1 , X_train_rfc.shape[1] ))
X_test = np.reshape(X_test_rfc, ( X_test_rfc.shape[0], 1,  X_test_rfc.shape[1] ))

# %%
model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train_rfc.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Flatten())
model.add(Dense(units=50))
# output layer with softmax activation
model.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 1, 64)             25088
#
#  dropout_2 (Dropout)         (None, 1, 64)             0
#
#  lstm_4 (LSTM)               (None, 1, 64)             33024
#
#  dropout_3 (Dropout)         (None, 1, 64)             0
#
#  lstm_5 (LSTM)               (None, 1, 64)             33024
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 50)                3250
#
#  dense_3 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 94641 (369.69 KB)
# Trainable params: 94641 (369.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 5/5 [==============================] - 8s 422ms/step - loss: 1.5996 - accuracy: 0.3946 - val_loss: 1.5809 - val_accuracy: 0.4301
# Epoch 2/100
# 5/5 [==============================] - 0s 63ms/step - loss: 1.5686 - accuracy: 0.5444 - val_loss: 1.5453 - val_accuracy: 0.6084
# Epoch 3/100
# 5/5 [==============================] - 0s 64ms/step - loss: 1.5294 - accuracy: 0.5916 - val_loss: 1.4972 - val_accuracy: 0.6767
# Epoch 4/100
# 5/5 [==============================] - 0s 62ms/step - loss: 1.4753 - accuracy: 0.6197 - val_loss: 1.4289 - val_accuracy: 0.6808
# Epoch 5/100
# 5/5 [==============================] - 0s 65ms/step - loss: 1.3983 - accuracy: 0.6433 - val_loss: 1.3326 - val_accuracy: 0.6825
# Epoch 6/100
# 5/5 [==============================] - 0s 71ms/step - loss: 1.2936 - accuracy: 0.6515 - val_loss: 1.2107 - val_accuracy: 0.6838
# Epoch 7/100
# 5/5 [==============================] - 0s 71ms/step - loss: 1.1760 - accuracy: 0.6651 - val_loss: 1.0995 - val_accuracy: 0.6869
# Epoch 8/100
# 5/5 [==============================] - 0s 63ms/step - loss: 1.0839 - accuracy: 0.6820 - val_loss: 1.0153 - val_accuracy: 0.6926
# Epoch 9/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.9956 - accuracy: 0.6898 - val_loss: 0.9042 - val_accuracy: 0.6879
# Epoch 10/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.8859 - accuracy: 0.6881 - val_loss: 0.8037 - val_accuracy: 0.6924
# Epoch 11/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.8024 - accuracy: 0.6956 - val_loss: 0.7467 - val_accuracy: 0.7049
# Epoch 12/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.7555 - accuracy: 0.7082 - val_loss: 0.7138 - val_accuracy: 0.7186
# Epoch 13/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.7248 - accuracy: 0.7171 - val_loss: 0.6879 - val_accuracy: 0.7225
# Epoch 14/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.7000 - accuracy: 0.7206 - val_loss: 0.6665 - val_accuracy: 0.7262
# Epoch 15/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.6806 - accuracy: 0.7229 - val_loss: 0.6467 - val_accuracy: 0.7289
# Epoch 16/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6613 - accuracy: 0.7253 - val_loss: 0.6280 - val_accuracy: 0.7333
# Epoch 17/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.6434 - accuracy: 0.7296 - val_loss: 0.6094 - val_accuracy: 0.7395
# Epoch 18/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.6253 - accuracy: 0.7434 - val_loss: 0.5898 - val_accuracy: 0.7702
# Epoch 19/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.6075 - accuracy: 0.7663 - val_loss: 0.5695 - val_accuracy: 0.7866
# Epoch 20/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.5846 - accuracy: 0.7839 - val_loss: 0.5479 - val_accuracy: 0.8001
# Epoch 21/100
# 5/5 [==============================] - 0s 72ms/step - loss: 0.5640 - accuracy: 0.8010 - val_loss: 0.5245 - val_accuracy: 0.8210
# Epoch 22/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.5404 - accuracy: 0.8156 - val_loss: 0.5000 - val_accuracy: 0.8352
# Epoch 23/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.5160 - accuracy: 0.8281 - val_loss: 0.4745 - val_accuracy: 0.8412
# Epoch 24/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.4894 - accuracy: 0.8342 - val_loss: 0.4494 - val_accuracy: 0.8404
# Epoch 25/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.4671 - accuracy: 0.8365 - val_loss: 0.4273 - val_accuracy: 0.8424
# Epoch 26/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.4469 - accuracy: 0.8379 - val_loss: 0.4090 - val_accuracy: 0.8444
# Epoch 27/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.4296 - accuracy: 0.8386 - val_loss: 0.3953 - val_accuracy: 0.8460
# Epoch 28/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.4175 - accuracy: 0.8410 - val_loss: 0.3848 - val_accuracy: 0.8476
# Epoch 29/100
# 5/5 [==============================] - 0s 80ms/step - loss: 0.4086 - accuracy: 0.8406 - val_loss: 0.3766 - val_accuracy: 0.8482
# Epoch 30/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.3994 - accuracy: 0.8434 - val_loss: 0.3690 - val_accuracy: 0.8505
# Epoch 31/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.3940 - accuracy: 0.8464 - val_loss: 0.3625 - val_accuracy: 0.8524
# Epoch 32/100
# 5/5 [==============================] - 0s 72ms/step - loss: 0.3863 - accuracy: 0.8499 - val_loss: 0.3562 - val_accuracy: 0.8546
# Epoch 33/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.3807 - accuracy: 0.8527 - val_loss: 0.3505 - val_accuracy: 0.8600
# Epoch 34/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.3731 - accuracy: 0.8605 - val_loss: 0.3457 - val_accuracy: 0.8714
# Epoch 35/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.3698 - accuracy: 0.8650 - val_loss: 0.3404 - val_accuracy: 0.8740
# Epoch 36/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.3625 - accuracy: 0.8672 - val_loss: 0.3359 - val_accuracy: 0.8743
# Epoch 37/100
# 5/5 [==============================] - 0s 68ms/step - loss: 0.3586 - accuracy: 0.8702 - val_loss: 0.3306 - val_accuracy: 0.8763
# Epoch 38/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.3541 - accuracy: 0.8695 - val_loss: 0.3262 - val_accuracy: 0.8789
# Epoch 39/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.3455 - accuracy: 0.8710 - val_loss: 0.3207 - val_accuracy: 0.8778
# Epoch 40/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3419 - accuracy: 0.8719 - val_loss: 0.3164 - val_accuracy: 0.8817
# Epoch 41/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.3356 - accuracy: 0.8705 - val_loss: 0.3115 - val_accuracy: 0.8834
# Epoch 42/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.3315 - accuracy: 0.8738 - val_loss: 0.3066 - val_accuracy: 0.8789
# Epoch 43/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.3267 - accuracy: 0.8727 - val_loss: 0.3019 - val_accuracy: 0.8816
# Epoch 44/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.3219 - accuracy: 0.8747 - val_loss: 0.2976 - val_accuracy: 0.8824
# Epoch 45/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.3159 - accuracy: 0.8758 - val_loss: 0.2934 - val_accuracy: 0.8853
# Epoch 46/100
# 5/5 [==============================] - 0s 78ms/step - loss: 0.3116 - accuracy: 0.8780 - val_loss: 0.2892 - val_accuracy: 0.8888
# Epoch 47/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.3091 - accuracy: 0.8807 - val_loss: 0.2854 - val_accuracy: 0.8897
# Epoch 48/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.3052 - accuracy: 0.8815 - val_loss: 0.2819 - val_accuracy: 0.8886
# Epoch 49/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.3018 - accuracy: 0.8826 - val_loss: 0.2785 - val_accuracy: 0.8920
# Epoch 50/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.2999 - accuracy: 0.8842 - val_loss: 0.2754 - val_accuracy: 0.8937
# Epoch 51/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2960 - accuracy: 0.8866 - val_loss: 0.2720 - val_accuracy: 0.8957
# Epoch 52/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.2917 - accuracy: 0.8878 - val_loss: 0.2693 - val_accuracy: 0.8952
# Epoch 53/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.2883 - accuracy: 0.8901 - val_loss: 0.2661 - val_accuracy: 0.8969
# Epoch 54/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.2862 - accuracy: 0.8896 - val_loss: 0.2635 - val_accuracy: 0.8964
# Epoch 55/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2836 - accuracy: 0.8922 - val_loss: 0.2606 - val_accuracy: 0.8974
# Epoch 56/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.2817 - accuracy: 0.8935 - val_loss: 0.2583 - val_accuracy: 0.8994
# Epoch 57/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.2759 - accuracy: 0.8966 - val_loss: 0.2559 - val_accuracy: 0.9010
# Epoch 58/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.2739 - accuracy: 0.8973 - val_loss: 0.2535 - val_accuracy: 0.9020
# Epoch 59/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.2708 - accuracy: 0.8991 - val_loss: 0.2515 - val_accuracy: 0.9023
# Epoch 60/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2692 - accuracy: 0.8994 - val_loss: 0.2491 - val_accuracy: 0.9045
# Epoch 61/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2667 - accuracy: 0.9019 - val_loss: 0.2470 - val_accuracy: 0.9097
# Epoch 62/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.2644 - accuracy: 0.9018 - val_loss: 0.2451 - val_accuracy: 0.9077
# Epoch 63/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.2647 - accuracy: 0.9038 - val_loss: 0.2431 - val_accuracy: 0.9133
# Epoch 64/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.2605 - accuracy: 0.9053 - val_loss: 0.2412 - val_accuracy: 0.9143
# Epoch 65/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.2592 - accuracy: 0.9048 - val_loss: 0.2393 - val_accuracy: 0.9145
# Epoch 66/100
# 5/5 [==============================] - 0s 68ms/step - loss: 0.2577 - accuracy: 0.9049 - val_loss: 0.2372 - val_accuracy: 0.9160
# Epoch 67/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.2551 - accuracy: 0.9078 - val_loss: 0.2355 - val_accuracy: 0.9165
# Epoch 68/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.2548 - accuracy: 0.9080 - val_loss: 0.2340 - val_accuracy: 0.9156
# Epoch 69/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.2521 - accuracy: 0.9072 - val_loss: 0.2324 - val_accuracy: 0.9160
# Epoch 70/100
# 5/5 [==============================] - 0s 80ms/step - loss: 0.2510 - accuracy: 0.9091 - val_loss: 0.2306 - val_accuracy: 0.9167
# Epoch 71/100
# 5/5 [==============================] - 0s 94ms/step - loss: 0.2481 - accuracy: 0.9089 - val_loss: 0.2295 - val_accuracy: 0.9177
# Epoch 72/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.2477 - accuracy: 0.9100 - val_loss: 0.2278 - val_accuracy: 0.9177
# Epoch 73/100
# 5/5 [==============================] - 0s 99ms/step - loss: 0.2453 - accuracy: 0.9095 - val_loss: 0.2259 - val_accuracy: 0.9173
# Epoch 74/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.2407 - accuracy: 0.9133 - val_loss: 0.2244 - val_accuracy: 0.9192
# Epoch 75/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.2421 - accuracy: 0.9123 - val_loss: 0.2231 - val_accuracy: 0.9195
# Epoch 76/100
# 5/5 [==============================] - 0s 95ms/step - loss: 0.2425 - accuracy: 0.9121 - val_loss: 0.2223 - val_accuracy: 0.9199
# Epoch 77/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.2377 - accuracy: 0.9130 - val_loss: 0.2204 - val_accuracy: 0.9205
# Epoch 78/100
# 5/5 [==============================] - 0s 99ms/step - loss: 0.2395 - accuracy: 0.9123 - val_loss: 0.2179 - val_accuracy: 0.9202
# Epoch 79/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.2337 - accuracy: 0.9141 - val_loss: 0.2165 - val_accuracy: 0.9210
# Epoch 80/100
# 5/5 [==============================] - 0s 88ms/step - loss: 0.2342 - accuracy: 0.9147 - val_loss: 0.2146 - val_accuracy: 0.9221
# Epoch 81/100
# 5/5 [==============================] - 0s 91ms/step - loss: 0.2327 - accuracy: 0.9147 - val_loss: 0.2132 - val_accuracy: 0.9219
# Epoch 82/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2300 - accuracy: 0.9150 - val_loss: 0.2116 - val_accuracy: 0.9232
# Epoch 83/100
# 5/5 [==============================] - 0s 91ms/step - loss: 0.2282 - accuracy: 0.9171 - val_loss: 0.2102 - val_accuracy: 0.9231
# Epoch 84/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.2270 - accuracy: 0.9163 - val_loss: 0.2086 - val_accuracy: 0.9248
# Epoch 85/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2248 - accuracy: 0.9168 - val_loss: 0.2076 - val_accuracy: 0.9246
# Epoch 86/100
# 5/5 [==============================] - 0s 97ms/step - loss: 0.2229 - accuracy: 0.9182 - val_loss: 0.2056 - val_accuracy: 0.9248
# Epoch 87/100
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2197 - accuracy: 0.9190 - val_loss: 0.2043 - val_accuracy: 0.9242
# Epoch 88/100
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2232 - accuracy: 0.9173 - val_loss: 0.2042 - val_accuracy: 0.9258
# Epoch 89/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.2218 - accuracy: 0.9180 - val_loss: 0.2009 - val_accuracy: 0.9259
# Epoch 90/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2181 - accuracy: 0.9196 - val_loss: 0.1995 - val_accuracy: 0.9266
# Epoch 91/100
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2178 - accuracy: 0.9182 - val_loss: 0.1985 - val_accuracy: 0.9268
# Epoch 92/100
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2159 - accuracy: 0.9189 - val_loss: 0.1969 - val_accuracy: 0.9276
# Epoch 93/100
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2143 - accuracy: 0.9204 - val_loss: 0.1951 - val_accuracy: 0.9278
# Epoch 94/100
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2141 - accuracy: 0.9187 - val_loss: 0.1934 - val_accuracy: 0.9281
# Epoch 95/100
# 5/5 [==============================] - 0s 94ms/step - loss: 0.2097 - accuracy: 0.9226 - val_loss: 0.1946 - val_accuracy: 0.9283
# Epoch 96/100
# 5/5 [==============================] - 0s 94ms/step - loss: 0.2115 - accuracy: 0.9199 - val_loss: 0.1930 - val_accuracy: 0.9288
# Epoch 97/100
# 5/5 [==============================] - 0s 94ms/step - loss: 0.2092 - accuracy: 0.9209 - val_loss: 0.1899 - val_accuracy: 0.9283
# Epoch 98/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2103 - accuracy: 0.9211 - val_loss: 0.1925 - val_accuracy: 0.9296
# Epoch 99/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2074 - accuracy: 0.9224 - val_loss: 0.1897 - val_accuracy: 0.9298
# Epoch 100/100
# 5/5 [==============================] - 0s 91ms/step - loss: 0.2094 - accuracy: 0.9212 - val_loss: 0.1862 - val_accuracy: 0.9296
