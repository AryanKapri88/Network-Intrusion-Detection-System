# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from tensorflow.keras.utils import plot_model
# Out:
# WARNING:tensorflow:From C:\Users\Binayak K\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
feature=["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
          "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations","num_shells",
          "num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count","serror_rate","srv_serror_rate",
          "rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count", 
          "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate","dst_host_srv_diff_host_rate","dst_host_serror_rate",
          "dst_host_srv_serror_rate","dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty"]

# %%
train='KDDTrain+.txt'
test='KDDTest+.txt'
test21='KDDTest-21.txt'

# %%
train_data=pd.read_csv(train,names=feature)
test_data=pd.read_csv(test,names=feature)
test_data21 = pd.read_csv(test21, names= feature)
data= pd.concat([train_data, test_data], ignore_index=True)

# %%
data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 148512         0           tcp      smtp   SF        794        333     0
# 148513         0           tcp      http   SF        317        938     0
# 148514         0           tcp      http   SF      54540       8314     0
# 148515         0           udp  domain_u   SF         42         42     0
# 148516         0           tcp    sunrpc  REJ          0          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 148512               0       0    0  ...                    0.72
# 148513               0       0    0  ...                    1.00
# 148514               0       0    2  ...                    1.00
# 148515               0       0    0  ...                    0.99
# 148516               0       0    0  ...                    0.08
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 148512                    0.06                         0.01
# 148513                    0.00                         0.01
# 148514                    0.00                         0.00
# 148515                    0.01                         0.00
# 148516                    0.03                         0.00
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 148512                         0.01                  0.01
# 148513                         0.01                  0.01
# 148514                         0.00                  0.00
# 148515                         0.00                  0.00
# 148516                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 148512                      0.00                  0.00
# 148513                      0.00                  0.00
# 148514                      0.00                  0.07
# 148515                      0.00                  0.00
# 148516                      0.00                  0.44
#
#         dst_host_srv_rerror_rate    label  difficulty
# 0                           0.00   normal          20
# 1                           0.00   normal          15
# 2                           0.00  neptune          19
# 3                           0.01   normal          21
# 4                           0.00   normal          21
# ...                          ...      ...         ...
# 148512                      0.00   normal          21
# 148513                      0.00   normal          21
# 148514                      0.07     back          15
# 148515                      0.00   normal          21
# 148516                      1.00    mscan          14
#
# [148517 rows x 43 columns]

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
#  12  num_compromised              148517 non-null  int64
#  13  root_shell                   148517 non-null  int64
#  14  su_attempted                 148517 non-null  int64
#  15  num_root                     148517 non-null  int64
#  16  num_file_creations           148517 non-null  int64
#  17  num_shells                   148517 non-null  int64
#  18  num_access_files             148517 non-null  int64
#  19  num_outbound_cmds            148517 non-null  int64
#  20  is_host_login                148517 non-null  int64
#  21  is_guest_login               148517 non-null  int64
#  22  count                        148517 non-null  int64
#  23  srv_count                    148517 non-null  int64
#  24  serror_rate                  148517 non-null  float64
#  25  srv_serror_rate              148517 non-null  float64
#  26  rerror_rate                  148517 non-null  float64
#  27  srv_rerror_rate              148517 non-null  float64
#  28  same_srv_rate                148517 non-null  float64
#  29  diff_srv_rate                148517 non-null  float64
#  30  srv_diff_host_rate           148517 non-null  float64
#  31  dst_host_count               148517 non-null  int64
#  32  dst_host_srv_count           148517 non-null  int64
#  33  dst_host_same_srv_rate       148517 non-null  float64
#  34  dst_host_diff_srv_rate       148517 non-null  float64
#  35  dst_host_same_src_port_rate  148517 non-null  float64
#  36  dst_host_srv_diff_host_rate  148517 non-null  float64
#  37  dst_host_serror_rate         148517 non-null  float64
#  38  dst_host_srv_serror_rate     148517 non-null  float64
#  39  dst_host_rerror_rate         148517 non-null  float64
#  40  dst_host_srv_rerror_rate     148517 non-null  float64
#  41  label                        148517 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 47.6+ MB

# %%
data.describe().T
# Out:
#                                 count          mean           std  min    25%  \
# duration                     148517.0    276.779305  2.460683e+03  0.0   0.00
# src_bytes                    148517.0  40227.949299  5.409612e+06  0.0   0.00
# dst_bytes                    148517.0  17088.853593  3.703525e+06  0.0   0.00
# land                         148517.0      0.000215  1.467714e-02  0.0   0.00
# wrong_fragment               148517.0      0.020523  2.400691e-01  0.0   0.00
# urgent                       148517.0      0.000202  1.941708e-02  0.0   0.00
# hot                          148517.0      0.189379  2.013160e+00  0.0   0.00
# num_failed_logins            148517.0      0.004323  7.224823e-02  0.0   0.00
# logged_in                    148517.0      0.402789  4.904606e-01  0.0   0.00
# num_compromised              148517.0      0.255062  2.223137e+01  0.0   0.00
# root_shell                   148517.0      0.001508  3.880696e-02  0.0   0.00
# su_attempted                 148517.0      0.000976  4.238907e-02  0.0   0.00
# num_root                     148517.0      0.273726  2.268902e+01  0.0   0.00
# num_file_creations           148517.0      0.012073  5.178631e-01  0.0   0.00
# num_shells                   148517.0      0.000525  2.770051e-02  0.0   0.00
# num_access_files             148517.0      0.004013  9.525663e-02  0.0   0.00
# num_outbound_cmds            148517.0      0.000000  0.000000e+00  0.0   0.00
# is_host_login                148517.0      0.000081  8.988484e-03  0.0   0.00
# is_guest_login               148517.0      0.012308  1.102585e-01  0.0   0.00
# count                        148517.0     83.336561  1.167607e+02  0.0   2.00
# srv_count                    148517.0     28.251937  7.536963e+01  0.0   2.00
# serror_rate                  148517.0      0.256925  4.319178e-01  0.0   0.00
# srv_serror_rate              148517.0      0.255337  4.325783e-01  0.0   0.00
# rerror_rate                  148517.0      0.137947  3.393872e-01  0.0   0.00
# srv_rerror_rate              148517.0      0.138487  3.417829e-01  0.0   0.00
# same_srv_rate                148517.0      0.672983  4.365437e-01  0.0   0.10
# diff_srv_rate                148517.0      0.067761  1.946658e-01  0.0   0.00
# srv_diff_host_rate           148517.0      0.097441  2.588856e-01  0.0   0.00
# dst_host_count               148517.0    183.928042  9.852833e+01  0.0  87.00
# dst_host_srv_count           148517.0    119.462661  1.112323e+02  0.0  11.00
# dst_host_same_srv_rate       148517.0      0.534521  4.480612e-01  0.0   0.05
# dst_host_diff_srv_rate       148517.0      0.084103  1.941020e-01  0.0   0.00
# dst_host_same_src_port_rate  148517.0      0.145932  3.086376e-01  0.0   0.00
# dst_host_srv_diff_host_rate  148517.0      0.030584  1.089751e-01  0.0   0.00
# dst_host_serror_rate         148517.0      0.256122  4.284996e-01  0.0   0.00
# dst_host_srv_serror_rate     148517.0      0.251304  4.297194e-01  0.0   0.00
# dst_host_rerror_rate         148517.0      0.136220  3.227411e-01  0.0   0.00
# dst_host_srv_rerror_rate     148517.0      0.136397  3.352823e-01  0.0   0.00
#
#                                 50%     75%           max
# duration                       0.00    0.00  5.771500e+04
# src_bytes                     44.00  278.00  1.379964e+09
# dst_bytes                      0.00  571.00  1.309937e+09
# land                           0.00    0.00  1.000000e+00
# wrong_fragment                 0.00    0.00  3.000000e+00
# urgent                         0.00    0.00  3.000000e+00
# hot                            0.00    0.00  1.010000e+02
# num_failed_logins              0.00    0.00  5.000000e+00
# logged_in                      0.00    1.00  1.000000e+00
# num_compromised                0.00    0.00  7.479000e+03
# root_shell                     0.00    0.00  1.000000e+00
# su_attempted                   0.00    0.00  2.000000e+00
# num_root                       0.00    0.00  7.468000e+03
# num_file_creations             0.00    0.00  1.000000e+02
# num_shells                     0.00    0.00  5.000000e+00
# num_access_files               0.00    0.00  9.000000e+00
# num_outbound_cmds              0.00    0.00  0.000000e+00
# is_host_login                  0.00    0.00  1.000000e+00
# is_guest_login                 0.00    0.00  1.000000e+00
# count                         13.00  141.00  5.110000e+02
# srv_count                      7.00   17.00  5.110000e+02
# serror_rate                    0.00    0.85  1.000000e+00
# srv_serror_rate                0.00    0.91  1.000000e+00
# rerror_rate                    0.00    0.00  1.000000e+00
# srv_rerror_rate                0.00    0.00  1.000000e+00
# same_srv_rate                  1.00    1.00  1.000000e+00
# diff_srv_rate                  0.00    0.06  1.000000e+00
# srv_diff_host_rate             0.00    0.00  1.000000e+00
# dst_host_count               255.00  255.00  2.550000e+02
# dst_host_srv_count            72.00  255.00  2.550000e+02
# dst_host_same_srv_rate         0.60    1.00  1.000000e+00
# dst_host_diff_srv_rate         0.02    0.07  1.000000e+00
# dst_host_same_src_port_rate    0.00    0.05  1.000000e+00
# dst_host_srv_diff_host_rate    0.00    0.01  1.000000e+00
# dst_host_serror_rate           0.00    0.60  1.000000e+00
# dst_host_srv_serror_rate       0.00    0.50  1.000000e+00
# dst_host_rerror_rate           0.00    0.00  1.000000e+00
# dst_host_srv_rerror_rate       0.00    0.00  1.000000e+00

# %%
# number of attack labels 
data['label'].value_counts()
# Out:
# label
# normal             77054
# neptune            45871
# satan               4368
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: count, dtype: int64

# %%
# Redistribute across common attack class
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail','snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)      
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# label
# normal    77054
# Dos       53387
# Probe     14077
# R2L        3880
# U2R         119
# Name: count, dtype: int64

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
label = pd.DataFrame(data.label)

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = label.apply(le2.fit_transform)
data['intrusion'] = enc_label
print(data.shape)
data
# Out:
# (148517, 43)
#         duration protocol_type   service flag  src_bytes  dst_bytes     land  \
# 0      -0.112481           tcp  ftp_data   SF  -0.007346  -0.004614 -0.01468
# 1      -0.112481           udp     other   SF  -0.007409  -0.004614 -0.01468
# 2      -0.112481           tcp   private   S0  -0.007436  -0.004614 -0.01468
# 3      -0.112481           tcp      http   SF  -0.007394  -0.002413 -0.01468
# 4      -0.112481           tcp      http   SF  -0.007400  -0.004501 -0.01468
# ...          ...           ...       ...  ...        ...        ...      ...
# 148512 -0.112481           tcp      smtp   SF  -0.007290  -0.004524 -0.01468
# 148513 -0.112481           tcp      http   SF  -0.007378  -0.004361 -0.01468
# 148514 -0.112481           tcp      http   SF   0.002646  -0.002369 -0.01468
# 148515 -0.112481           udp  domain_u   SF  -0.007429  -0.004603 -0.01468
# 148516 -0.112481           tcp    sunrpc  REJ  -0.007436  -0.004614 -0.01468
#
#         wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0            -0.085488 -0.010403 -0.094071  ...               -0.813554
# 1            -0.085488 -0.010403 -0.094071  ...               -1.192968
# 2            -0.085488 -0.010403 -0.094071  ...               -0.969783
# 3            -0.085488 -0.010403 -0.094071  ...                1.038878
# 4            -0.085488 -0.010403 -0.094071  ...                1.038878
# ...                ...       ...       ...  ...                     ...
# 148512       -0.085488 -0.010403 -0.094071  ...                0.413961
# 148513       -0.085488 -0.010403 -0.094071  ...                1.038878
# 148514       -0.085488 -0.010403  0.899396  ...                1.038878
# 148515       -0.085488 -0.010403 -0.094071  ...                1.016560
# 148516       -0.085488 -0.010403 -0.094071  ...               -1.014420
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    -0.278736                     0.077981
# 1                     2.657874                     2.378421
# 2                    -0.175697                    -0.472829
# 3                    -0.433294                    -0.375627
# 4                    -0.433294                    -0.472829
# ...                        ...                          ...
# 148512               -0.124178                    -0.440428
# 148513               -0.433294                    -0.440428
# 148514               -0.433294                    -0.472829
# 148515               -0.381775                    -0.472829
# 148516               -0.278736                    -0.472829
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         -0.280650             -0.597720
# 1                         -0.280650             -0.597720
# 2                         -0.280650              1.736012
# 3                          0.086408             -0.527708
# 4                         -0.280650             -0.597720
# ...                             ...                   ...
# 148512                    -0.188885             -0.574382
# 148513                    -0.188885             -0.574382
# 148514                    -0.280650             -0.597720
# 148515                    -0.280650             -0.597720
# 148516                    -0.280650             -0.597720
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      -0.584813             -0.267151
# 1                      -0.584813             -0.422074
# 2                       1.742295             -0.422074
# 3                      -0.561542             -0.422074
# 4                      -0.584813             -0.422074
# ...                          ...                   ...
# 148512                 -0.584813             -0.422074
# 148513                 -0.584813             -0.422074
# 148514                 -0.584813             -0.205182
# 148515                 -0.584813             -0.422074
# 148516                 -0.584813              0.941252
#
#         dst_host_srv_rerror_rate   label  intrusion
# 0                      -0.406815  normal          4
# 1                      -0.406815  normal          4
# 2                      -0.406815     Dos          0
# 3                      -0.376989  normal          4
# 4                      -0.406815  normal          4
# ...                          ...     ...        ...
# 148512                 -0.406815  normal          4
# 148513                 -0.406815  normal          4
# 148514                 -0.198035     Dos          0
# 148515                 -0.406815  normal          4
# 148516                  2.575756   Probe          1
#
# [148517 rows x 43 columns]

# %%
data.drop(labels= ['label'], axis=1, inplace=True)
print(data.shape)
# Out:
# (148517, 42)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")  
print(data.shape)
# Out:
# (148517, 123)

# %%
y_data= data['intrusion']
X_data= data.drop(labels=['intrusion'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (148517, 122)
# y_train has shape: (148517,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
X_data = np.asarray(X_data).astype(np.float32)
Y_data = np.asarray(y_data).astype(np.float32)
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data, test_size=0.20, random_state=42)
print(X_train.shape,'\n',X_test.shape)
# Out:
# (118813, 122)
#  (29704, 122)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %%
model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Flatten())
model.add(Dense(units=50))
# output layer with softmax activation
model.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 1, 64)             47872
#
#  dropout_4 (Dropout)         (None, 1, 64)             0
#
#  lstm_7 (LSTM)               (None, 1, 64)             33024
#
#  dropout_5 (Dropout)         (None, 1, 64)             0
#
#  lstm_8 (LSTM)               (None, 1, 64)             33024
#
#  flatten_2 (Flatten)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 50)                3250
#
#  dense_5 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 117425 (458.69 KB)
# Trainable params: 117425 (458.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Binayak K\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Binayak K\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 20/20 [==============================] - 8s 131ms/step - loss: 1.5135 - accuracy: 0.7483 - val_loss: 1.3224 - val_accuracy: 0.8330
# Epoch 2/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.9448 - accuracy: 0.8391 - val_loss: 0.4945 - val_accuracy: 0.8421
# Epoch 3/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.4406 - accuracy: 0.8467 - val_loss: 0.3861 - val_accuracy: 0.8603
# Epoch 4/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.3552 - accuracy: 0.8993 - val_loss: 0.3179 - val_accuracy: 0.9230
# Epoch 5/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.2844 - accuracy: 0.9310 - val_loss: 0.2390 - val_accuracy: 0.9411
# Epoch 6/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.2144 - accuracy: 0.9407 - val_loss: 0.1867 - val_accuracy: 0.9442
# Epoch 7/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.1771 - accuracy: 0.9451 - val_loss: 0.1596 - val_accuracy: 0.9479
# Epoch 8/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.1527 - accuracy: 0.9485 - val_loss: 0.1378 - val_accuracy: 0.9497
# Epoch 9/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.1323 - accuracy: 0.9510 - val_loss: 0.1199 - val_accuracy: 0.9523
# Epoch 10/100
# 20/20 [==============================] - 1s 73ms/step - loss: 0.1171 - accuracy: 0.9566 - val_loss: 0.1064 - val_accuracy: 0.9625
# Epoch 11/100
# 20/20 [==============================] - 2s 76ms/step - loss: 0.1072 - accuracy: 0.9623 - val_loss: 0.0983 - val_accuracy: 0.9655
# Epoch 12/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0995 - accuracy: 0.9660 - val_loss: 0.0906 - val_accuracy: 0.9716
# Epoch 13/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0923 - accuracy: 0.9696 - val_loss: 0.0844 - val_accuracy: 0.9735
# Epoch 14/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0876 - accuracy: 0.9721 - val_loss: 0.0797 - val_accuracy: 0.9750
# Epoch 15/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0815 - accuracy: 0.9733 - val_loss: 0.0741 - val_accuracy: 0.9771
# Epoch 16/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0779 - accuracy: 0.9749 - val_loss: 0.0710 - val_accuracy: 0.9784
# Epoch 17/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0797 - accuracy: 0.9740 - val_loss: 0.0685 - val_accuracy: 0.9791
# Epoch 18/100
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0715 - accuracy: 0.9772 - val_loss: 0.0642 - val_accuracy: 0.9799
# Epoch 19/100
# 20/20 [==============================] - 2s 74ms/step - loss: 0.0676 - accuracy: 0.9780 - val_loss: 0.0613 - val_accuracy: 0.9811
# Epoch 20/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0652 - accuracy: 0.9782 - val_loss: 0.0586 - val_accuracy: 0.9821
# Epoch 21/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0626 - accuracy: 0.9791 - val_loss: 0.0570 - val_accuracy: 0.9825
# Epoch 22/100
# 20/20 [==============================] - 1s 74ms/step - loss: 0.0626 - accuracy: 0.9794 - val_loss: 0.0553 - val_accuracy: 0.9827
# Epoch 23/100
# 20/20 [==============================] - 1s 71ms/step - loss: 0.0592 - accuracy: 0.9804 - val_loss: 0.0533 - val_accuracy: 0.9834
# Epoch 24/100
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0577 - accuracy: 0.9809 - val_loss: 0.0525 - val_accuracy: 0.9837
# Epoch 25/100
# 20/20 [==============================] - 1s 73ms/step - loss: 0.0583 - accuracy: 0.9802 - val_loss: 0.0515 - val_accuracy: 0.9845
# Epoch 26/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0554 - accuracy: 0.9814 - val_loss: 0.0501 - val_accuracy: 0.9846
# Epoch 27/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0547 - accuracy: 0.9815 - val_loss: 0.0497 - val_accuracy: 0.9840
# Epoch 28/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.0541 - accuracy: 0.9820 - val_loss: 0.0488 - val_accuracy: 0.9852
# Epoch 29/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0528 - accuracy: 0.9820 - val_loss: 0.0477 - val_accuracy: 0.9850
# Epoch 30/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0512 - accuracy: 0.9829 - val_loss: 0.0473 - val_accuracy: 0.9856
# Epoch 31/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0511 - accuracy: 0.9833 - val_loss: 0.0468 - val_accuracy: 0.9850
# Epoch 32/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.0513 - accuracy: 0.9827 - val_loss: 0.0460 - val_accuracy: 0.9854
# Epoch 33/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0497 - accuracy: 0.9836 - val_loss: 0.0455 - val_accuracy: 0.9854
# Epoch 34/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0516 - accuracy: 0.9820 - val_loss: 0.0460 - val_accuracy: 0.9852
# Epoch 35/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0484 - accuracy: 0.9841 - val_loss: 0.0448 - val_accuracy: 0.9859
# Epoch 36/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0479 - accuracy: 0.9840 - val_loss: 0.0447 - val_accuracy: 0.9859
# Epoch 37/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0486 - accuracy: 0.9838 - val_loss: 0.0443 - val_accuracy: 0.9862
# Epoch 38/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0479 - accuracy: 0.9836 - val_loss: 0.0441 - val_accuracy: 0.9855
# Epoch 39/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0468 - accuracy: 0.9843 - val_loss: 0.0433 - val_accuracy: 0.9859
# Epoch 40/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0466 - accuracy: 0.9843 - val_loss: 0.0432 - val_accuracy: 0.9863
# Epoch 41/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0454 - accuracy: 0.9848 - val_loss: 0.0425 - val_accuracy: 0.9869
# Epoch 42/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0455 - accuracy: 0.9848 - val_loss: 0.0423 - val_accuracy: 0.9872
# Epoch 43/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0454 - accuracy: 0.9848 - val_loss: 0.0421 - val_accuracy: 0.9871
# Epoch 44/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0452 - accuracy: 0.9845 - val_loss: 0.0420 - val_accuracy: 0.9872
# Epoch 45/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0445 - accuracy: 0.9853 - val_loss: 0.0417 - val_accuracy: 0.9871
# Epoch 46/100
# 20/20 [==============================] - 1s 73ms/step - loss: 0.0439 - accuracy: 0.9852 - val_loss: 0.0417 - val_accuracy: 0.9873
# Epoch 47/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0430 - accuracy: 0.9857 - val_loss: 0.0411 - val_accuracy: 0.9870
# Epoch 48/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0438 - accuracy: 0.9849 - val_loss: 0.0412 - val_accuracy: 0.9867
# Epoch 49/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0438 - accuracy: 0.9849 - val_loss: 0.0416 - val_accuracy: 0.9871
# Epoch 50/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0436 - accuracy: 0.9851 - val_loss: 0.0405 - val_accuracy: 0.9872
# Epoch 51/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0422 - accuracy: 0.9858 - val_loss: 0.0402 - val_accuracy: 0.9874
# Epoch 52/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0427 - accuracy: 0.9854 - val_loss: 0.0402 - val_accuracy: 0.9878
# Epoch 53/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0417 - accuracy: 0.9860 - val_loss: 0.0398 - val_accuracy: 0.9870
# Epoch 54/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.0420 - accuracy: 0.9856 - val_loss: 0.0401 - val_accuracy: 0.9867
# Epoch 55/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0412 - accuracy: 0.9860 - val_loss: 0.0396 - val_accuracy: 0.9869
# Epoch 56/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0416 - accuracy: 0.9856 - val_loss: 0.0397 - val_accuracy: 0.9868
# Epoch 57/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0421 - accuracy: 0.9852 - val_loss: 0.0390 - val_accuracy: 0.9869
# Epoch 58/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0406 - accuracy: 0.9864 - val_loss: 0.0387 - val_accuracy: 0.9876
# Epoch 59/100
# 20/20 [==============================] - 1s 71ms/step - loss: 0.0396 - accuracy: 0.9865 - val_loss: 0.0387 - val_accuracy: 0.9875
# Epoch 60/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0396 - accuracy: 0.9863 - val_loss: 0.0387 - val_accuracy: 0.9879
# Epoch 61/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0399 - accuracy: 0.9866 - val_loss: 0.0387 - val_accuracy: 0.9867
# Epoch 62/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0399 - accuracy: 0.9862 - val_loss: 0.0383 - val_accuracy: 0.9881
# Epoch 63/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0400 - accuracy: 0.9861 - val_loss: 0.0385 - val_accuracy: 0.9874
# Epoch 64/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0390 - accuracy: 0.9870 - val_loss: 0.0380 - val_accuracy: 0.9871
# Epoch 65/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0395 - accuracy: 0.9863 - val_loss: 0.0378 - val_accuracy: 0.9882
# Epoch 66/100
# 20/20 [==============================] - 2s 83ms/step - loss: 0.0403 - accuracy: 0.9861 - val_loss: 0.0386 - val_accuracy: 0.9868
# Epoch 67/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0395 - accuracy: 0.9862 - val_loss: 0.0374 - val_accuracy: 0.9882
# Epoch 68/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0393 - accuracy: 0.9866 - val_loss: 0.0384 - val_accuracy: 0.9874
# Epoch 69/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0406 - accuracy: 0.9861 - val_loss: 0.0381 - val_accuracy: 0.9870
# Epoch 70/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0378 - accuracy: 0.9869 - val_loss: 0.0374 - val_accuracy: 0.9880
# Epoch 71/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0373 - accuracy: 0.9876 - val_loss: 0.0370 - val_accuracy: 0.9882
# Epoch 72/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0376 - accuracy: 0.9870 - val_loss: 0.0371 - val_accuracy: 0.9879
# Epoch 73/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0371 - accuracy: 0.9871 - val_loss: 0.0366 - val_accuracy: 0.9886
# Epoch 74/100
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0365 - accuracy: 0.9872 - val_loss: 0.0364 - val_accuracy: 0.9883
# Epoch 75/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0361 - accuracy: 0.9880 - val_loss: 0.0365 - val_accuracy: 0.9881
# Epoch 76/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0364 - accuracy: 0.9877 - val_loss: 0.0364 - val_accuracy: 0.9882
# Epoch 77/100
# 20/20 [==============================] - 1s 72ms/step - loss: 0.0382 - accuracy: 0.9867 - val_loss: 0.0369 - val_accuracy: 0.9878
# Epoch 78/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0375 - accuracy: 0.9872 - val_loss: 0.0367 - val_accuracy: 0.9883
# Epoch 79/100
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0366 - accuracy: 0.9875 - val_loss: 0.0361 - val_accuracy: 0.9880
# Epoch 80/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.0371 - accuracy: 0.9874 - val_loss: 0.0366 - val_accuracy: 0.9879
# Epoch 81/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0365 - accuracy: 0.9878 - val_loss: 0.0363 - val_accuracy: 0.9878
# Epoch 82/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0364 - accuracy: 0.9878 - val_loss: 0.0365 - val_accuracy: 0.9878
# Epoch 83/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0376 - accuracy: 0.9872 - val_loss: 0.0361 - val_accuracy: 0.9886
# Epoch 84/100
# 20/20 [==============================] - 1s 76ms/step - loss: 0.0350 - accuracy: 0.9885 - val_loss: 0.0356 - val_accuracy: 0.9881
# Epoch 85/100
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0368 - accuracy: 0.9875 - val_loss: 0.0360 - val_accuracy: 0.9887
# Epoch 86/100
# 20/20 [==============================] - 1s 61ms/step - loss: 0.0353 - accuracy: 0.9880 - val_loss: 0.0362 - val_accuracy: 0.9882
# Epoch 87/100
# 20/20 [==============================] - 1s 75ms/step - loss: 0.0363 - accuracy: 0.9873 - val_loss: 0.0352 - val_accuracy: 0.9888
# Epoch 88/100
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0349 - accuracy: 0.9882 - val_loss: 0.0358 - val_accuracy: 0.9883
# Epoch 89/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0347 - accuracy: 0.9886 - val_loss: 0.0352 - val_accuracy: 0.9891
# Epoch 90/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.0355 - accuracy: 0.9877 - val_loss: 0.0356 - val_accuracy: 0.9878
# Epoch 91/100
# 20/20 [==============================] - 1s 69ms/step - loss: 0.0343 - accuracy: 0.9877 - val_loss: 0.0348 - val_accuracy: 0.9889
# Epoch 92/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0361 - accuracy: 0.9878 - val_loss: 0.0362 - val_accuracy: 0.9875
# Epoch 93/100
# 20/20 [==============================] - 1s 70ms/step - loss: 0.0360 - accuracy: 0.9873 - val_loss: 0.0349 - val_accuracy: 0.9888
# Epoch 94/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.0335 - accuracy: 0.9888 - val_loss: 0.0348 - val_accuracy: 0.9887
# Epoch 95/100
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0351 - accuracy: 0.9884 - val_loss: 0.0356 - val_accuracy: 0.9892
# Epoch 96/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0343 - accuracy: 0.9884 - val_loss: 0.0344 - val_accuracy: 0.9891
# Epoch 97/100
# 20/20 [==============================] - 1s 67ms/step - loss: 0.0332 - accuracy: 0.9887 - val_loss: 0.0342 - val_accuracy: 0.9894
# Epoch 98/100
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0336 - accuracy: 0.9885 - val_loss: 0.0341 - val_accuracy: 0.9894
# Epoch 99/100
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0334 - accuracy: 0.9881 - val_loss: 0.0342 - val_accuracy: 0.9888
# Epoch 100/100
# 20/20 [==============================] - 1s 72ms/step - loss: 0.0342 - accuracy: 0.9883 - val_loss: 0.0344 - val_accuracy: 0.9884

# %%
# predicting target attribute on testing dataset
test_results = model.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 929/929 [==============================] - 2s 2ms/step - loss: 0.0368 - accuracy: 0.9878
# Test results - Loss: 0.03682200238108635 - Accuracy: 98.7779438495636%

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
