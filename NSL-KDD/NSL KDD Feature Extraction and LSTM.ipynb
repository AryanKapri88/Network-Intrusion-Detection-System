# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
from tensorflow.keras.utils import plot_model
# Out:
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25186         0           tcp      exec  RSTO          0          0     0
# 25187         0           tcp  ftp_data    SF        334          0     0
# 25188         0           tcp   private   REJ          0          0     0
# 25189         0           tcp      nnsp    S0          0          0     0
# 25190         0           tcp    finger    S0          0          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.00
# 1                   0       0    0  ...                    0.10
# 2                   0       0    0  ...                    1.00
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 25186               0       0    0  ...                    0.03
# 25187               0       0    0  ...                    1.00
# 25188               0       0    0  ...                    0.05
# 25189               0       0    0  ...                    0.08
# 25190               0       0    0  ...                    0.19
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 25186                    0.06                         0.00
# 25187                    0.00                         1.00
# 25188                    0.07                         0.00
# 25189                    0.06                         0.00
# 25190                    0.03                         0.01
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 25186                         0.00                  0.00
# 25187                         0.18                  0.00
# 25188                         0.00                  0.00
# 25189                         0.00                  1.00
# 25190                         0.00                  1.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                   0.0
# 1                          1.00                   0.0
# 2                          0.01                   0.0
# 3                          0.00                   0.0
# 4                          0.00                   1.0
# ...                         ...                   ...
# 25186                      0.00                   1.0
# 25187                      0.00                   0.0
# 25188                      0.00                   1.0
# 25189                      1.00                   0.0
# 25190                      1.00                   0.0
#
#        Dst_host_srv_rerror_rate  attack_type  difficulty_level
# 0                          0.00       normal                15
# 1                          0.00      neptune                19
# 2                          0.01       normal                21
# 3                          0.00       normal                21
# 4                          1.00      neptune                21
# ...                         ...          ...               ...
# 25186                      1.00      neptune                19
# 25187                      0.00  warezclient                12
# 25188                      1.00      neptune                21
# 25189                      0.00      neptune                20
# 25190                      0.00      neptune                18
#
# [25191 rows x 43 columns]

# %%
test_data
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0            13           tcp    telnet    SF        118       2425     0
# 1             0           udp   private    SF         44          0     0
# 2             0           tcp    telnet    S3          0         44     0
# 3             0           udp   private    SF         53         55     0
# 4             0           tcp   private    SH          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 11845         0           udp  domain_u    SF         43         43     0
# 11846         0           tcp      http    SF        336        285     0
# 11847         1           tcp    telnet  RSTO          0         15     0
# 11848         0           tcp    sunrpc   REJ          0          0     0
# 11849         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.38
# 1                   0       0    0  ...                    1.00
# 2                   0       0    0  ...                    0.31
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.06
# ...               ...     ...  ...  ...                     ...
# 11845               0       0    0  ...                    1.00
# 11846               0       0    0  ...                    0.92
# 11847               0       0    0  ...                    0.37
# 11848               0       0    0  ...                    0.19
# 11849               0       0    0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.12                         0.04
# 1                        0.01                         0.01
# 2                        0.61                         0.00
# 3                        0.00                         0.87
# 4                        1.00                         1.00
# ...                       ...                          ...
# 11845                    0.00                         0.01
# 11846                    0.02                         0.00
# 11847                    0.03                         0.01
# 11848                    0.03                         0.01
# 11849                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  0.00
# 2                             0.00                  0.21
# 3                             0.00                  0.00
# 4                             0.00                  1.00
# ...                            ...                   ...
# 11845                         0.00                  0.00
# 11846                         0.00                  0.00
# 11847                         0.02                  0.05
# 11848                         0.04                  0.00
# 11849                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.12
# 1                          0.00                  0.00
# 2                          0.68                  0.60
# 3                          0.00                  0.00
# 4                          1.00                  0.00
# ...                         ...                   ...
# 11845                      0.00                  0.00
# 11846                      0.00                  0.05
# 11847                      0.08                  0.85
# 11848                      0.00                  0.88
# 11849                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate   attack_type  difficulty_level
# 0                          0.30  guess_passwd                 2
# 1                          0.00     snmpguess                12
# 2                          0.00  processtable                18
# 3                          0.00        normal                17
# 4                          0.00          nmap                17
# ...                         ...           ...               ...
# 11845                      0.00        normal                18
# 11846                      0.00        normal                18
# 11847                      0.58         mscan                13
# 11848                      1.00         mscan                15
# 11849                      0.00     snmpguess                17
#
# [11850 rows x 43 columns]

# %%
df= pd.concat([train_data, test_data], ignore_index=True)
df
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 37036         0           udp  domain_u    SF         43         43     0
# 37037         0           tcp      http    SF        336        285     0
# 37038         1           tcp    telnet  RSTO          0         15     0
# 37039         0           tcp    sunrpc   REJ          0          0     0
# 37040         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.00
# 1                   0       0    0  ...                    0.10
# 2                   0       0    0  ...                    1.00
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 37036               0       0    0  ...                    1.00
# 37037               0       0    0  ...                    0.92
# 37038               0       0    0  ...                    0.37
# 37039               0       0    0  ...                    0.19
# 37040               0       0    0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 37036                    0.00                         0.01
# 37037                    0.02                         0.00
# 37038                    0.03                         0.01
# 37039                    0.03                         0.01
# 37040                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 37036                         0.00                  0.00
# 37037                         0.00                  0.00
# 37038                         0.02                  0.05
# 37039                         0.04                  0.00
# 37040                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.00
# 1                          1.00                  0.00
# 2                          0.01                  0.00
# 3                          0.00                  0.00
# 4                          0.00                  1.00
# ...                         ...                   ...
# 37036                      0.00                  0.00
# 37037                      0.00                  0.05
# 37038                      0.08                  0.85
# 37039                      0.00                  0.88
# 37040                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate  attack_type  difficulty_level
# 0                          0.00       normal                15
# 1                          0.00      neptune                19
# 2                          0.01       normal                21
# 3                          0.00       normal                21
# 4                          1.00      neptune                21
# ...                         ...          ...               ...
# 37036                      0.00       normal                18
# 37037                      0.00       normal                18
# 37038                      0.58        mscan                13
# 37039                      1.00        mscan                15
# 37040                      0.00    snmpguess                17
#
# [37041 rows x 43 columns]

# %%
df = df.rename(columns={'attack_type': 'Label', 'difficulty_level': 'Difficulty'})
df
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 37036         0           udp  domain_u    SF         43         43     0
# 37037         0           tcp      http    SF        336        285     0
# 37038         1           tcp    telnet  RSTO          0         15     0
# 37039         0           tcp    sunrpc   REJ          0          0     0
# 37040         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.00
# 1                   0       0    0  ...                    0.10
# 2                   0       0    0  ...                    1.00
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 37036               0       0    0  ...                    1.00
# 37037               0       0    0  ...                    0.92
# 37038               0       0    0  ...                    0.37
# 37039               0       0    0  ...                    0.19
# 37040               0       0    0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 37036                    0.00                         0.01
# 37037                    0.02                         0.00
# 37038                    0.03                         0.01
# 37039                    0.03                         0.01
# 37040                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 37036                         0.00                  0.00
# 37037                         0.00                  0.00
# 37038                         0.02                  0.05
# 37039                         0.04                  0.00
# 37040                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.00
# 1                          1.00                  0.00
# 2                          0.01                  0.00
# 3                          0.00                  0.00
# 4                          0.00                  1.00
# ...                         ...                   ...
# 37036                      0.00                  0.00
# 37037                      0.00                  0.05
# 37038                      0.08                  0.85
# 37039                      0.00                  0.88
# 37040                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate      Label  Difficulty
# 0                          0.00     normal          15
# 1                          0.00    neptune          19
# 2                          0.01     normal          21
# 3                          0.00     normal          21
# 4                          1.00    neptune          21
# ...                         ...        ...         ...
# 37036                      0.00     normal          18
# 37037                      0.00     normal          18
# 37038                      0.58      mscan          13
# 37039                      1.00      mscan          15
# 37040                      0.00  snmpguess          17
#
# [37041 rows x 43 columns]

# %%
df.drop(['Difficulty'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37041 entries, 0 to 37040
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Duration                     37041 non-null  int64
#  1   Protocol_type                37041 non-null  object
#  2   Service                      37041 non-null  object
#  3   Flag                         37041 non-null  object
#  4   Src_bytes                    37041 non-null  int64
#  5   Dst_bytes                    37041 non-null  int64
#  6   Land                         37041 non-null  int64
#  7   Wrong_fragment               37041 non-null  int64
#  8   Urgent                       37041 non-null  int64
#  9   Hot                          37041 non-null  int64
#  10  Num_failed_logins            37041 non-null  int64
#  11  Logged_in                    37041 non-null  int64
#  12  Num_compromised              37041 non-null  int64
#  13  Root_shell                   37041 non-null  int64
#  14  Su_attempted                 37041 non-null  int64
#  15  Num_root                     37041 non-null  int64
#  16  Num_file_creations           37041 non-null  int64
#  17  Num_shells                   37041 non-null  int64
#  18  Num_access_files             37041 non-null  int64
#  19  Num_outbound_cmds            37041 non-null  int64
#  20  Is_hot_login                 37041 non-null  int64
#  21  Is_guest_login               37041 non-null  int64
#  22  Count                        37041 non-null  int64
#  23  Srv_count                    37041 non-null  int64
#  24  Serror_rate                  37041 non-null  float64
#  25  Srv_serror_rate              37041 non-null  float64
#  26  Rerror_rate                  37041 non-null  float64
#  27  Srv_rerror_rate              37041 non-null  float64
#  28  Same_srv_rate                37041 non-null  float64
#  29  Diff_srv_rate                37041 non-null  float64
#  30  Srv_diff_host_rate           37041 non-null  float64
#  31  Dst_host_count               37041 non-null  int64
#  32  Dst_host_srv_count           37041 non-null  int64
#  33  Dst_host_same_srv_rate       37041 non-null  float64
#  34  Dst_host_diff_srv_rate       37041 non-null  float64
#  35  Dst_host_same_src_port_rate  37041 non-null  float64
#  36  Dst_host_srv_diff_host_rate  37041 non-null  float64
#  37  Dst_host_serror_rate         37041 non-null  float64
#  38  Dst_host_srv_serror_rate     37041 non-null  float64
#  39  Dst_host_rerror_rate         37041 non-null  float64
#  40  Dst_host_srv_rerror_rate     37041 non-null  float64
#  41  Label                        37041 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 11.9+ MB

# %%
df.columns
# Out:
# Index(['Duration', 'Protocol_type', 'Service', 'Flag', 'Src_bytes',
#        'Dst_bytes', 'Land', 'Wrong_fragment', 'Urgent', 'Hot',
#        'Num_failed_logins', 'Logged_in', 'Num_compromised', 'Root_shell',
#        'Su_attempted', 'Num_root', 'Num_file_creations', 'Num_shells',
#        'Num_access_files', 'Num_outbound_cmds', 'Is_hot_login',
#        'Is_guest_login', 'Count', 'Srv_count', 'Serror_rate',
#        'Srv_serror_rate', 'Rerror_rate', 'Srv_rerror_rate', 'Same_srv_rate',
#        'Diff_srv_rate', 'Srv_diff_host_rate', 'Dst_host_count',
#        'Dst_host_srv_count', 'Dst_host_same_srv_rate',
#        'Dst_host_diff_srv_rate', 'Dst_host_same_src_port_rate',
#        'Dst_host_srv_diff_host_rate', 'Dst_host_serror_rate',
#        'Dst_host_srv_serror_rate', 'Dst_host_rerror_rate',
#        'Dst_host_srv_rerror_rate', 'Label'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Duration                       0
# Protocol_type                  0
# Service                        0
# Flag                           0
# Src_bytes                      0
# Dst_bytes                      0
# Land                           0
# Wrong_fragment                 0
# Urgent                         0
# Hot                            0
# Num_failed_logins              0
# Logged_in                      0
# Num_compromised                0
# Root_shell                     0
# Su_attempted                   0
# Num_root                       0
# Num_file_creations             0
# Num_shells                     0
# Num_access_files               0
# Num_outbound_cmds              0
# Is_hot_login                   0
# Is_guest_login                 0
# Count                          0
# Srv_count                      0
# Serror_rate                    0
# Srv_serror_rate                0
# Rerror_rate                    0
# Srv_rerror_rate                0
# Same_srv_rate                  0
# Diff_srv_rate                  0
# Srv_diff_host_rate             0
# Dst_host_count                 0
# Dst_host_srv_count             0
# Dst_host_same_srv_rate         0
# Dst_host_diff_srv_rate         0
# Dst_host_same_src_port_rate    0
# Dst_host_srv_diff_host_rate    0
# Dst_host_serror_rate           0
# Dst_host_srv_serror_rate       0
# Dst_host_rerror_rate           0
# Dst_host_srv_rerror_rate       0
# Label                          0
# dtype: int64

# %%
df['Label'].value_counts()
# Out:
# normal             15600
# neptune             9861
# satan               1418
# guess_passwd        1241
# smurf               1156
# mscan                996
# warezmaster          951
# ipsweep              851
# portsweep            743
# apache2              737
# processtable         685
# back                 555
# nmap                 374
# snmpguess            331
# saint                309
# mailbomb             293
# teardrop             200
# warezclient          181
# snmpgetattack        178
# httptunnel           133
# pod                   79
# buffer_overflow       26
# multihop              20
# named                 17
# rootkit               17
# ps                    15
# sendmail              14
# xterm                 13
# xlock                  9
# land                   8
# imap                   6
# phf                    4
# xsnoop                 4
# ftp_write              4
# loadmodule             3
# worm                   2
# udpstorm               2
# perl                   2
# sqlattack              2
# spy                    1
# Name: Label, dtype: int64

# %%
# Redistribute across common attack class
def change_label(df):
  df.Label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.Label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail','snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)      
  df.Label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.Label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(df)

# %%
df
# Out:
#        Duration Protocol_type   Service  Flag  Src_bytes  Dst_bytes  Land  \
# 0             0           udp     other    SF        146          0     0
# 1             0           tcp   private    S0          0          0     0
# 2             0           tcp      http    SF        232       8153     0
# 3             0           tcp      http    SF        199        420     0
# 4             0           tcp   private   REJ          0          0     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 37036         0           udp  domain_u    SF         43         43     0
# 37037         0           tcp      http    SF        336        285     0
# 37038         1           tcp    telnet  RSTO          0         15     0
# 37039         0           tcp    sunrpc   REJ          0          0     0
# 37040         0           udp   private    SF         41          0     0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_srv_count  \
# 0                   0       0    0  ...                   1
# 1                   0       0    0  ...                  26
# 2                   0       0    0  ...                 255
# 3                   0       0    0  ...                 255
# 4                   0       0    0  ...                  19
# ...               ...     ...  ...  ...                 ...
# 37036               0       0    0  ...                 255
# 37037               0       0    0  ...                 234
# 37038               0       0    0  ...                  96
# 37039               0       0    0  ...                  52
# 37040               0       0    0  ...                 255
#
#        Dst_host_same_srv_rate  Dst_host_diff_srv_rate  \
# 0                        0.00                    0.60
# 1                        0.10                    0.05
# 2                        1.00                    0.00
# 3                        1.00                    0.00
# 4                        0.07                    0.07
# ...                       ...                     ...
# 37036                    1.00                    0.00
# 37037                    0.92                    0.02
# 37038                    0.37                    0.03
# 37039                    0.19                    0.03
# 37040                    1.00                    0.00
#
#        Dst_host_same_src_port_rate  Dst_host_srv_diff_host_rate  \
# 0                             0.88                         0.00
# 1                             0.00                         0.00
# 2                             0.03                         0.04
# 3                             0.00                         0.00
# 4                             0.00                         0.00
# ...                            ...                          ...
# 37036                         0.01                         0.00
# 37037                         0.00                         0.00
# 37038                         0.01                         0.02
# 37039                         0.01                         0.04
# 37040                         0.00                         0.00
#
#        Dst_host_serror_rate  Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                      0.00                      0.00                  0.00
# 1                      1.00                      1.00                  0.00
# 2                      0.03                      0.01                  0.00
# 3                      0.00                      0.00                  0.00
# 4                      0.00                      0.00                  1.00
# ...                     ...                       ...                   ...
# 37036                  0.00                      0.00                  0.00
# 37037                  0.00                      0.00                  0.05
# 37038                  0.05                      0.08                  0.85
# 37039                  0.00                      0.00                  0.88
# 37040                  0.00                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate   Label
# 0                          0.00  normal
# 1                          0.00     Dos
# 2                          0.01  normal
# 3                          0.00  normal
# 4                          1.00     Dos
# ...                         ...     ...
# 37036                      0.00  normal
# 37037                      0.00  normal
# 37038                      0.58   Probe
# 37039                      1.00   Probe
# 37040                      0.00     R2L
#
# [37041 rows x 42 columns]

# %%
df['Label'].value_counts()
# Out:
# normal    15600
# Dos       13578
# Probe      4691
# R2L        3094
# U2R          78
# Name: Label, dtype: int64

# %%
Label = pd.DataFrame(df.Label)

# %%
std_scaler = MinMaxScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = df.select_dtypes(include='number').columns
df = standardization(df,numeric_col)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = Label.apply(le2.fit_transform)
df['intrusion'] = enc_label
print(df.shape)
df
# Out:
# (37041, 43)
#        Duration Protocol_type   Service  Flag     Src_bytes  Dst_bytes  Land  \
# 0      0.000000           udp     other    SF  3.824902e-07   0.000000   0.0
# 1      0.000000           tcp   private    S0  0.000000e+00   0.000000   0.0
# 2      0.000000           tcp      http    SF  6.077927e-07   0.001583   0.0
# 3      0.000000           tcp      http    SF  5.213394e-07   0.000082   0.0
# 4      0.000000           tcp   private   REJ  0.000000e+00   0.000000   0.0
# ...         ...           ...       ...   ...           ...        ...   ...
# 37036  0.000000           udp  domain_u    SF  1.126512e-07   0.000008   0.0
# 37037  0.000000           tcp      http    SF  8.802515e-07   0.000055   0.0
# 37038  0.000017           tcp    telnet  RSTO  0.000000e+00   0.000003   0.0
# 37039  0.000000           tcp    sunrpc   REJ  0.000000e+00   0.000000   0.0
# 37040  0.000000           udp   private    SF  1.074116e-07   0.000000   0.0
#
#        Wrong_fragment  Urgent  Hot  ...  Dst_host_same_srv_rate  \
# 0                 0.0     0.0  0.0  ...                    0.00
# 1                 0.0     0.0  0.0  ...                    0.10
# 2                 0.0     0.0  0.0  ...                    1.00
# 3                 0.0     0.0  0.0  ...                    1.00
# 4                 0.0     0.0  0.0  ...                    0.07
# ...               ...     ...  ...  ...                     ...
# 37036             0.0     0.0  0.0  ...                    1.00
# 37037             0.0     0.0  0.0  ...                    0.92
# 37038             0.0     0.0  0.0  ...                    0.37
# 37039             0.0     0.0  0.0  ...                    0.19
# 37040             0.0     0.0  0.0  ...                    1.00
#
#        Dst_host_diff_srv_rate  Dst_host_same_src_port_rate  \
# 0                        0.60                         0.88
# 1                        0.05                         0.00
# 2                        0.00                         0.03
# 3                        0.00                         0.00
# 4                        0.07                         0.00
# ...                       ...                          ...
# 37036                    0.00                         0.01
# 37037                    0.02                         0.00
# 37038                    0.03                         0.01
# 37039                    0.03                         0.01
# 37040                    0.00                         0.00
#
#        Dst_host_srv_diff_host_rate  Dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  1.00
# 2                             0.04                  0.03
# 3                             0.00                  0.00
# 4                             0.00                  0.00
# ...                            ...                   ...
# 37036                         0.00                  0.00
# 37037                         0.00                  0.00
# 37038                         0.02                  0.05
# 37039                         0.04                  0.00
# 37040                         0.00                  0.00
#
#        Dst_host_srv_serror_rate  Dst_host_rerror_rate  \
# 0                          0.00                  0.00
# 1                          1.00                  0.00
# 2                          0.01                  0.00
# 3                          0.00                  0.00
# 4                          0.00                  1.00
# ...                         ...                   ...
# 37036                      0.00                  0.00
# 37037                      0.00                  0.05
# 37038                      0.08                  0.85
# 37039                      0.00                  0.88
# 37040                      0.00                  0.00
#
#        Dst_host_srv_rerror_rate   Label  intrusion
# 0                          0.00  normal          4
# 1                          0.00     Dos          0
# 2                          0.01  normal          4
# 3                          0.00  normal          4
# 4                          1.00     Dos          0
# ...                         ...     ...        ...
# 37036                      0.00  normal          4
# 37037                      0.00  normal          4
# 37038                      0.58   Probe          1
# 37039                      1.00   Probe          1
# 37040                      0.00     R2L          2
#
# [37041 rows x 43 columns]

# %%
df.drop(labels= ['Label'], axis=1, inplace=True)
print(df.shape)
# Out:
# (37041, 42)

# %%
# one-hot-encoding categorical columns
df = pd.get_dummies(df,columns=['Protocol_type','Service','Flag'],prefix="",prefix_sep="")  
print(df.shape)
# Out:
# (37041, 120)

# %%
y_data= df['intrusion']
X_data= df.drop(labels=['intrusion'], axis=1)

# %%
X_data = X_data.astype(np.float32)
Y_data = y_data.astype(np.float32)
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data, test_size=0.20, random_state=42)
print(X_train.shape,'\n',X_test.shape)
# Out:
# (29632, 119)
#  (7409, 119)

# %%
from sklearn.feature_selection import SelectFromModel

sel = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1))
sel.fit(X_train, y_train)
sel.get_support()

X_train.columns

features = X_train.columns[sel.get_support()]
print(features)

print(len(features))

np.mean(sel.estimator_.feature_importances_)
print(sel.estimator_.feature_importances_)
# Out:
# Index(['Duration', 'Src_bytes', 'Dst_bytes', 'Hot', 'Logged_in', 'Count',
#        'Srv_count', 'Serror_rate', 'Srv_serror_rate', 'Rerror_rate',
#        'Srv_rerror_rate', 'Same_srv_rate', 'Diff_srv_rate',
#        'Srv_diff_host_rate', 'Dst_host_count', 'Dst_host_srv_count',
#        'Dst_host_same_srv_rate', 'Dst_host_diff_srv_rate',
#        'Dst_host_same_src_port_rate', 'Dst_host_srv_diff_host_rate',
#        'Dst_host_serror_rate', 'Dst_host_srv_serror_rate',
#        'Dst_host_rerror_rate', 'Dst_host_srv_rerror_rate', 'icmp', 'tcp',
#        'udp', 'eco_i', 'ecr_i', 'http', 'pop_3', 'S0', 'SF'],
#       dtype='object')
# 33
# [2.09564406e-02 3.88128096e-02 7.56408263e-02 4.43256425e-05
#  3.90636857e-03 1.45080039e-04 1.05647110e-02 6.16775228e-03
#  2.12423697e-02 5.40708891e-03 4.12056775e-04 6.86001758e-05
#  7.93499604e-04 5.07356917e-04 2.63110707e-04 2.65870999e-04
#  0.00000000e+00 1.23102309e-04 5.53616524e-03 5.09232635e-02
#  3.09880814e-02 2.40804058e-02 2.83556444e-02 1.64953923e-02
#  1.25517438e-02 4.80709482e-02 3.57491381e-02 1.45877809e-02
#  2.77188102e-02 3.74361498e-02 3.99153236e-02 3.69864648e-02
#  3.42839145e-02 2.68259633e-02 2.65189467e-02 4.09119229e-02
#  4.37405137e-02 2.43710626e-02 1.81991419e-02 8.90941721e-03
#  1.08259273e-02 3.03914221e-04 1.23621270e-04 1.65204329e-05
#  2.77708879e-04 5.55339443e-06 4.01113786e-05 1.05145385e-05
#  1.41715340e-05 8.81050711e-06 7.70480718e-06 1.40521766e-04
#  5.62261427e-03 1.04184232e-05 1.19145132e-02 1.30192979e-02
#  3.44655226e-06 4.87214768e-07 7.20879258e-04 5.43438169e-03
#  5.45337705e-03 3.01047501e-05 7.16592350e-06 1.45874095e-02
#  1.50351229e-05 1.16207640e-06 8.70370358e-04 1.60998234e-05
#  2.40073568e-06 1.52322043e-06 8.44760552e-07 1.29579747e-05
#  3.16754132e-05 1.15765611e-05 8.84123217e-06 7.88278917e-06
#  4.33924284e-06 7.22961419e-06 3.99976716e-06 1.08049456e-05
#  1.17486006e-05 4.22421197e-05 7.03743709e-03 2.44879845e-04
#  2.32297907e-06 1.33588266e-02 0.00000000e+00 7.65144575e-03
#  4.71238284e-06 1.93401104e-05 4.45220232e-06 7.23984236e-06
#  3.78100237e-03 3.00054784e-06 1.23392732e-05 4.54986295e-04
#  2.71605563e-05 7.81249919e-06 5.59008908e-03 0.00000000e+00
#  1.69056493e-04 2.16759757e-04 1.12849961e-05 5.52146432e-04
#  4.55472475e-05 3.08211900e-05 5.69221660e-06 4.74264350e-05
#  5.04812966e-05 2.23310775e-03 1.43532087e-03 1.31223146e-04
#  5.20078151e-03 2.53085319e-02 3.41898057e-04 6.63691944e-05
#  7.25171399e-04 3.56195844e-02 1.48427305e-03]

# %%
X_train_rfc = sel.transform(X_train)
X_test_rfc = sel.transform(X_test)

X_train_rfc=np.array(X_train_rfc)
X_test_rfc=np.array(X_test_rfc)

from sklearn.preprocessing import LabelBinarizer
y_train = LabelBinarizer().fit_transform(y_train)
y_test = LabelBinarizer().fit_transform(y_test)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train_rfc, ( X_train_rfc.shape[0], 1 , X_train_rfc.shape[1] ))
X_test = np.reshape(X_test_rfc, ( X_test_rfc.shape[0], 1,  X_test_rfc.shape[1] ))

# %%
model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train_rfc.shape[1])))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Flatten())
model.add(Dense(units=50))
# output layer with softmax activation
model.add(Dense(units=5,activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 64)             25088
#
#  dropout (Dropout)           (None, 1, 64)             0
#
#  lstm_1 (LSTM)               (None, 1, 64)             33024
#
#  dropout_1 (Dropout)         (None, 1, 64)             0
#
#  lstm_2 (LSTM)               (None, 1, 64)             33024
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 50)                3250
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 94641 (369.69 KB)
# Trainable params: 94641 (369.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\aryan\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 5/5 [==============================] - 8s 456ms/step - loss: 1.5986 - accuracy: 0.3935 - val_loss: 1.5792 - val_accuracy: 0.4238
# Epoch 2/100
# 5/5 [==============================] - 0s 83ms/step - loss: 1.5663 - accuracy: 0.4415 - val_loss: 1.5416 - val_accuracy: 0.4238
# Epoch 3/100
# 5/5 [==============================] - 0s 93ms/step - loss: 1.5249 - accuracy: 0.4358 - val_loss: 1.4911 - val_accuracy: 0.4238
# Epoch 4/100
# 5/5 [==============================] - 1s 112ms/step - loss: 1.4683 - accuracy: 0.4310 - val_loss: 1.4203 - val_accuracy: 0.4238
# Epoch 5/100
# 5/5 [==============================] - 1s 148ms/step - loss: 1.3897 - accuracy: 0.4256 - val_loss: 1.3236 - val_accuracy: 0.4238
# Epoch 6/100
# 5/5 [==============================] - 1s 176ms/step - loss: 1.2868 - accuracy: 0.4231 - val_loss: 1.2127 - val_accuracy: 0.4238
# Epoch 7/100
# 5/5 [==============================] - 1s 163ms/step - loss: 1.1904 - accuracy: 0.4273 - val_loss: 1.1343 - val_accuracy: 0.4240
# Epoch 8/100
# 5/5 [==============================] - 1s 200ms/step - loss: 1.1283 - accuracy: 0.5785 - val_loss: 1.0687 - val_accuracy: 0.6921
# Epoch 9/100
# 5/5 [==============================] - 1s 170ms/step - loss: 1.0512 - accuracy: 0.6918 - val_loss: 0.9658 - val_accuracy: 0.7007
# Epoch 10/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.9424 - accuracy: 0.6964 - val_loss: 0.8515 - val_accuracy: 0.6985
# Epoch 11/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.8375 - accuracy: 0.6999 - val_loss: 0.7631 - val_accuracy: 0.7047
# Epoch 12/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.7666 - accuracy: 0.7067 - val_loss: 0.7174 - val_accuracy: 0.7186
# Epoch 13/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.7290 - accuracy: 0.7158 - val_loss: 0.6877 - val_accuracy: 0.7253
# Epoch 14/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.7020 - accuracy: 0.7203 - val_loss: 0.6624 - val_accuracy: 0.7289
# Epoch 15/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.6763 - accuracy: 0.7243 - val_loss: 0.6406 - val_accuracy: 0.7363
# Epoch 16/100
# 5/5 [==============================] - 1s 202ms/step - loss: 0.6554 - accuracy: 0.7349 - val_loss: 0.6193 - val_accuracy: 0.7549
# Epoch 17/100
# 5/5 [==============================] - 1s 204ms/step - loss: 0.6337 - accuracy: 0.7570 - val_loss: 0.5974 - val_accuracy: 0.7795
# Epoch 18/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.6145 - accuracy: 0.7710 - val_loss: 0.5755 - val_accuracy: 0.7864
# Epoch 19/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.5915 - accuracy: 0.7853 - val_loss: 0.5526 - val_accuracy: 0.8039
# Epoch 20/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.5691 - accuracy: 0.8052 - val_loss: 0.5289 - val_accuracy: 0.8250
# Epoch 21/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.5448 - accuracy: 0.8207 - val_loss: 0.5038 - val_accuracy: 0.8331
# Epoch 22/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.5213 - accuracy: 0.8267 - val_loss: 0.4779 - val_accuracy: 0.8382
# Epoch 23/100
# 5/5 [==============================] - 1s 147ms/step - loss: 0.4959 - accuracy: 0.8318 - val_loss: 0.4542 - val_accuracy: 0.8395
# Epoch 24/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.4747 - accuracy: 0.8337 - val_loss: 0.4343 - val_accuracy: 0.8436
# Epoch 25/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.4553 - accuracy: 0.8365 - val_loss: 0.4187 - val_accuracy: 0.8455
# Epoch 26/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.4414 - accuracy: 0.8372 - val_loss: 0.4071 - val_accuracy: 0.8456
# Epoch 27/100
# 5/5 [==============================] - 1s 147ms/step - loss: 0.4308 - accuracy: 0.8384 - val_loss: 0.3972 - val_accuracy: 0.8461
# Epoch 28/100
# 5/5 [==============================] - 1s 169ms/step - loss: 0.4232 - accuracy: 0.8389 - val_loss: 0.3888 - val_accuracy: 0.8480
# Epoch 29/100
# 5/5 [==============================] - 1s 157ms/step - loss: 0.4131 - accuracy: 0.8402 - val_loss: 0.3814 - val_accuracy: 0.8492
# Epoch 30/100
# 5/5 [==============================] - 1s 155ms/step - loss: 0.4074 - accuracy: 0.8410 - val_loss: 0.3752 - val_accuracy: 0.8515
# Epoch 31/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.4007 - accuracy: 0.8413 - val_loss: 0.3695 - val_accuracy: 0.8512
# Epoch 32/100
# 5/5 [==============================] - 1s 160ms/step - loss: 0.3953 - accuracy: 0.8445 - val_loss: 0.3646 - val_accuracy: 0.8514
# Epoch 33/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.3889 - accuracy: 0.8463 - val_loss: 0.3595 - val_accuracy: 0.8529
# Epoch 34/100
# 5/5 [==============================] - 1s 141ms/step - loss: 0.3836 - accuracy: 0.8458 - val_loss: 0.3551 - val_accuracy: 0.8536
# Epoch 35/100
# 5/5 [==============================] - 1s 147ms/step - loss: 0.3801 - accuracy: 0.8498 - val_loss: 0.3506 - val_accuracy: 0.8556
# Epoch 36/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.3748 - accuracy: 0.8513 - val_loss: 0.3465 - val_accuracy: 0.8573
# Epoch 37/100
# 5/5 [==============================] - 1s 148ms/step - loss: 0.3727 - accuracy: 0.8539 - val_loss: 0.3427 - val_accuracy: 0.8615
# Epoch 38/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.3669 - accuracy: 0.8588 - val_loss: 0.3387 - val_accuracy: 0.8762
# Epoch 39/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.3632 - accuracy: 0.8636 - val_loss: 0.3343 - val_accuracy: 0.8773
# Epoch 40/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.3580 - accuracy: 0.8674 - val_loss: 0.3301 - val_accuracy: 0.8782
# Epoch 41/100
# 5/5 [==============================] - 1s 135ms/step - loss: 0.3544 - accuracy: 0.8708 - val_loss: 0.3259 - val_accuracy: 0.8795
# Epoch 42/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.3498 - accuracy: 0.8740 - val_loss: 0.3215 - val_accuracy: 0.8799
# Epoch 43/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.3458 - accuracy: 0.8740 - val_loss: 0.3168 - val_accuracy: 0.8853
# Epoch 44/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.3391 - accuracy: 0.8761 - val_loss: 0.3115 - val_accuracy: 0.8873
# Epoch 45/100
# 5/5 [==============================] - 1s 145ms/step - loss: 0.3343 - accuracy: 0.8773 - val_loss: 0.3058 - val_accuracy: 0.8878
# Epoch 46/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.3234 - accuracy: 0.8796 - val_loss: 0.3003 - val_accuracy: 0.8875
# Epoch 47/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.3258 - accuracy: 0.8763 - val_loss: 0.2949 - val_accuracy: 0.8870
# Epoch 48/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.3179 - accuracy: 0.8797 - val_loss: 0.2895 - val_accuracy: 0.8902
# Epoch 49/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.3088 - accuracy: 0.8830 - val_loss: 0.2839 - val_accuracy: 0.8942
# Epoch 50/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.3054 - accuracy: 0.8836 - val_loss: 0.2791 - val_accuracy: 0.8946
# Epoch 51/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.3012 - accuracy: 0.8847 - val_loss: 0.2749 - val_accuracy: 0.8930
# Epoch 52/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.2937 - accuracy: 0.8876 - val_loss: 0.2707 - val_accuracy: 0.8939
# Epoch 53/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.2922 - accuracy: 0.8882 - val_loss: 0.2671 - val_accuracy: 0.8957
# Epoch 54/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.2874 - accuracy: 0.8907 - val_loss: 0.2638 - val_accuracy: 0.8972
# Epoch 55/100
# 5/5 [==============================] - 1s 135ms/step - loss: 0.2865 - accuracy: 0.8907 - val_loss: 0.2614 - val_accuracy: 0.8993
# Epoch 56/100
# 5/5 [==============================] - 1s 142ms/step - loss: 0.2837 - accuracy: 0.8934 - val_loss: 0.2593 - val_accuracy: 0.8998
# Epoch 57/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.2784 - accuracy: 0.8947 - val_loss: 0.2559 - val_accuracy: 0.9018
# Epoch 58/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.2751 - accuracy: 0.8958 - val_loss: 0.2535 - val_accuracy: 0.9028
# Epoch 59/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.2755 - accuracy: 0.8972 - val_loss: 0.2511 - val_accuracy: 0.9028
# Epoch 60/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.2713 - accuracy: 0.8985 - val_loss: 0.2488 - val_accuracy: 0.9030
# Epoch 61/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.2704 - accuracy: 0.8989 - val_loss: 0.2473 - val_accuracy: 0.9053
# Epoch 62/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.2683 - accuracy: 0.8995 - val_loss: 0.2454 - val_accuracy: 0.9045
# Epoch 63/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.2677 - accuracy: 0.8996 - val_loss: 0.2434 - val_accuracy: 0.9072
# Epoch 64/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.2631 - accuracy: 0.9023 - val_loss: 0.2418 - val_accuracy: 0.9074
# Epoch 65/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.2617 - accuracy: 0.9044 - val_loss: 0.2400 - val_accuracy: 0.9134
# Epoch 66/100
# 5/5 [==============================] - 1s 175ms/step - loss: 0.2595 - accuracy: 0.9027 - val_loss: 0.2380 - val_accuracy: 0.9129
# Epoch 67/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.2569 - accuracy: 0.9057 - val_loss: 0.2366 - val_accuracy: 0.9156
# Epoch 68/100
# 5/5 [==============================] - 1s 155ms/step - loss: 0.2565 - accuracy: 0.9054 - val_loss: 0.2350 - val_accuracy: 0.9138
# Epoch 69/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.2537 - accuracy: 0.9067 - val_loss: 0.2331 - val_accuracy: 0.9151
# Epoch 70/100
# 5/5 [==============================] - 1s 148ms/step - loss: 0.2519 - accuracy: 0.9068 - val_loss: 0.2314 - val_accuracy: 0.9165
# Epoch 71/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.2505 - accuracy: 0.9056 - val_loss: 0.2301 - val_accuracy: 0.9165
# Epoch 72/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.2500 - accuracy: 0.9081 - val_loss: 0.2288 - val_accuracy: 0.9160
# Epoch 73/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.2480 - accuracy: 0.9071 - val_loss: 0.2268 - val_accuracy: 0.9183
# Epoch 74/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.2461 - accuracy: 0.9090 - val_loss: 0.2248 - val_accuracy: 0.9190
# Epoch 75/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.2402 - accuracy: 0.9113 - val_loss: 0.2233 - val_accuracy: 0.9190
# Epoch 76/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.2445 - accuracy: 0.9101 - val_loss: 0.2219 - val_accuracy: 0.9194
# Epoch 77/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.2418 - accuracy: 0.9101 - val_loss: 0.2205 - val_accuracy: 0.9197
# Epoch 78/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.2384 - accuracy: 0.9121 - val_loss: 0.2188 - val_accuracy: 0.9199
# Epoch 79/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.2376 - accuracy: 0.9115 - val_loss: 0.2174 - val_accuracy: 0.9204
# Epoch 80/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.2347 - accuracy: 0.9121 - val_loss: 0.2160 - val_accuracy: 0.9199
# Epoch 81/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.2353 - accuracy: 0.9109 - val_loss: 0.2145 - val_accuracy: 0.9215
# Epoch 82/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.2311 - accuracy: 0.9148 - val_loss: 0.2136 - val_accuracy: 0.9205
# Epoch 83/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.2317 - accuracy: 0.9139 - val_loss: 0.2128 - val_accuracy: 0.9222
# Epoch 84/100
# 5/5 [==============================] - 1s 157ms/step - loss: 0.2316 - accuracy: 0.9142 - val_loss: 0.2107 - val_accuracy: 0.9222
# Epoch 85/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.2273 - accuracy: 0.9148 - val_loss: 0.2091 - val_accuracy: 0.9224
# Epoch 86/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.2275 - accuracy: 0.9144 - val_loss: 0.2071 - val_accuracy: 0.9227
# Epoch 87/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.2254 - accuracy: 0.9146 - val_loss: 0.2058 - val_accuracy: 0.9224
# Epoch 88/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.2237 - accuracy: 0.9160 - val_loss: 0.2036 - val_accuracy: 0.9236
# Epoch 89/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.2209 - accuracy: 0.9168 - val_loss: 0.2024 - val_accuracy: 0.9256
# Epoch 90/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.2221 - accuracy: 0.9147 - val_loss: 0.2011 - val_accuracy: 0.9242
# Epoch 91/100
# 5/5 [==============================] - 1s 160ms/step - loss: 0.2183 - accuracy: 0.9183 - val_loss: 0.2001 - val_accuracy: 0.9241
# Epoch 92/100
# 5/5 [==============================] - 1s 169ms/step - loss: 0.2158 - accuracy: 0.9183 - val_loss: 0.1982 - val_accuracy: 0.9258
# Epoch 93/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.2161 - accuracy: 0.9187 - val_loss: 0.1972 - val_accuracy: 0.9249
# Epoch 94/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.2159 - accuracy: 0.9182 - val_loss: 0.1961 - val_accuracy: 0.9273
# Epoch 95/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.2123 - accuracy: 0.9179 - val_loss: 0.1949 - val_accuracy: 0.9256
# Epoch 96/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.2138 - accuracy: 0.9192 - val_loss: 0.1930 - val_accuracy: 0.9266
# Epoch 97/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.2110 - accuracy: 0.9196 - val_loss: 0.1925 - val_accuracy: 0.9286
# Epoch 98/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.2104 - accuracy: 0.9177 - val_loss: 0.1909 - val_accuracy: 0.9275
# Epoch 99/100
# 5/5 [==============================] - 1s 190ms/step - loss: 0.2103 - accuracy: 0.9192 - val_loss: 0.1893 - val_accuracy: 0.9273
# Epoch 100/100
# 5/5 [==============================] - 1s 205ms/step - loss: 0.2068 - accuracy: 0.9219 - val_loss: 0.1886 - val_accuracy: 0.9283

# %%
test_results = model.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 232/232 [==============================] - 2s 9ms/step - loss: 0.1886 - accuracy: 0.9300
# Test results - Loss: 0.18863745033740997 - Accuracy: 92.99500584602356%
